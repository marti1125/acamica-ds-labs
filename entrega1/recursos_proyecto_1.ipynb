# %% [markdown]
# # Proyecto: Análisis mercado inmobiliario de la Ciudad de Buenos Aires

# %% [markdown]
# ¡Bienvenidos al primer proyecto de la carrera de Data Science de Acamica!
#
# En este proyecto vamos a trabajar con un dataset de propiedades en venta publicadas en el portal [Properati](www.properati.com.ar). El objetivo es dar los primeros pasos en el proceso de exploración de datos usando las herramientas que trabajamos en las activades.
#
# Vamos a enfocarnos en analizar algunos aspectos del mercado inmobiliario de la Ciudad de Buenos Aires pero para eso primero debemos limpiar un poco el dataset.

# %% [markdown]
# ## El dataset: propiedades en venta en Ciudad de Buenos Aires.

# %% [markdown]
# En este proyecto, trabajaremos con una muestra del conjunto de datos de propiedades en venta mencionado. En este dataset, cada fila es una propiedad en venta.
#
# ## Los atributos
# A continuación vamos a describir los atributos que consideramos en esta muestra:
#
# * **id**: id de la propiedad
# * **created_on**: fecha en la que la propiedad ingresó al sitio
# * **operation**: alquiler (rent) o venta (sell)
# * **property_type**: tipo de propiedad (casa, departamento, ph, etcétera)
# * **place_with_parent_names**: nombre del lugar donde se encuentra la propiedad según el publicador
# * **lat-lon**: coordenadas concatenadas
# * **lat**: latitud
# * **lon**: longitud
# * **price**: precio en la moneda especificada en currency
# * **currency**: divisa en la que está expresada la publicación
# * **price_aprox_usd**: precio aproximado en dólares estadounidenses
# * **surface_total_in_m2**: superficie total (en metros cuadrados)
# * **surface_covered_in_m2**: superficie cubierta (en metros cuadrados)
# * **price_usd_per_m2**: precio por metro cuadrado en dólares (precio dólares / superficie)
# * **floor**: número de piso (si corresponde)
# * **rooms**: cantidad de ambientes
# * **expenses**: expensas (si corresponde)
# * **barrio**: barrio según cartografía oficial
# * **properati_url**: url de la publicación en Properati

# %% [markdown]
# ## Importando las bibliotecas necesarias
#
# Para poder trabajar en la limpieza de datos y la visualización de nuestro dataset vamos a utilizar las bibliotecas numpy, pandas, matplotlib.pylab y seaborn.
#
# ** 1) Importá ** cada una de ellas con los siguientes nombres:
# - **numpy** como **np**
# - **pandas** como **pd**
# - **matplotlib.pylab** como **plt**
# - **seaborn** como **sns**

# %%
# Importar bibliotecas en esta celda
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# La siguiente línea es para ver las imagenes dentro del notebook
# %matplotlib inline
# Acá configuramos el tamaño de las figuras
plt.rcParams['figure.figsize'] = (12,8)
# Seteamos opciones de pandas sobre las columnas y su ancho
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)

# %% [markdown]
# ## Cargando dataset de propiedades
#
# **2) Cargá** el dataset que se encuentra en la carpeta *dataset/* y guardalo en una variable llamada **df**.
# No te olvides de utilizar **parse_dates** sobre la columna **created_on**

# %%
# cargá el dataset en esta celda
df = pd.read_csv('dataset/datos_properati.csv')
df
# Out:
#        created_on operation property_type  \
# 0      2017-09-22      sell         house
# 1      2017-08-01      sell         store
# 2      2017-08-02      sell         store
# 3      2017-08-03      sell         store
# 4      2017-08-08      sell         store
# 5      2017-08-09      sell         store
# 6      2017-08-11      sell         store
# 7      2017-08-11      sell         store
# 8      2017-08-12      sell         store
# 9      2017-08-15      sell         store
# 10     2017-08-15      sell         store
# 11     2017-08-16      sell         store
# 12     2017-08-16      sell         store
# 13     2017-08-18      sell         store
# 14     2017-08-26      sell         store
# 15     2017-08-26      sell         store
# 16     2017-08-29      sell         store
# 17     2017-08-29      sell         store
# 18     2017-08-29      sell     apartment
# 19     2017-08-29      sell     apartment
# 20     2017-08-29      sell     apartment
# 21     2017-08-30      sell         store
# 22     2017-08-30      sell         house
# 23     2017-08-30      sell         store
# 24     2017-08-30      sell     apartment
# 25     2017-08-30      sell            PH
# 26     2017-08-30      sell     apartment
# 27     2017-08-30      sell         house
# 28     2017-08-30      sell         house
# 29     2017-08-30      sell     apartment
# ...           ...       ...           ...
# 18949  2018-01-26      sell     apartment
# 18950  2018-01-26      sell            PH
# 18951  2018-01-26      sell         store
# 18952  2018-01-26      sell         house
# 18953  2018-01-26      sell            PH
# 18954  2018-01-26      sell            PH
# 18955  2018-01-26      sell     apartment
# 18956  2018-01-26      sell     apartment
# 18957  2018-01-27      sell            PH
# 18958  2018-01-28      sell     apartment
# 18959  2018-01-29      sell            PH
# 18960  2018-01-31      sell     apartment
# 18961  2018-01-31      sell         house
# 18962  2018-01-31      sell            PH
# 18963  2017-09-22      sell     apartment
# 18964  2017-09-30      sell     apartment
# 18965  2017-10-17      sell         house
# 18966  2017-10-17      sell         house
# 18967  2017-10-17      sell            PH
# 18968  2017-10-21      sell     apartment
# 18969  2017-10-21      sell         house
# 18970  2017-10-29      sell     apartment
# 18971  2017-10-29      sell     apartment
# 18972  2017-11-23      sell     apartment
# 18973  2017-12-17      sell     apartment
# 18974  2018-01-08      sell     apartment
# 18975  2018-01-23      sell         house
# 18976  2018-01-24      sell         store
# 18977  2018-01-27      sell     apartment
# 18978  2018-01-27      sell     apartment
#
#                                      place_with_parent_names  \
# 0          |Argentina|Capital Federal|Palermo|Palermo Viejo|
# 1                        |Argentina|Capital Federal|Palermo|
# 2           |Argentina|Capital Federal|Palermo|Palermo Soho|
# 3                        |Argentina|Capital Federal|Palermo|
# 4                   |Argentina|Capital Federal|Barrio Norte|
# 5                        |Argentina|Capital Federal|Palermo|
# 6                       |Argentina|Capital Federal|Belgrano|
# 7                        |Argentina|Capital Federal|Palermo|
# 8                        |Argentina|Capital Federal|Palermo|
# 9                        |Argentina|Capital Federal|Palermo|
# 10                       |Argentina|Capital Federal|Palermo|
# 11                  |Argentina|Capital Federal|Barrio Norte|
# 12     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 13                       |Argentina|Capital Federal|Palermo|
# 14                      |Argentina|Capital Federal|Belgrano|
# 15                       |Argentina|Capital Federal|Palermo|
# 16                       |Argentina|Capital Federal|Palermo|
# 17                       |Argentina|Capital Federal|Palermo|
# 18                       |Argentina|Capital Federal|Palermo|
# 19                       |Argentina|Capital Federal|Palermo|
# 20                       |Argentina|Capital Federal|Palermo|
# 21                       |Argentina|Capital Federal|Palermo|
# 22     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 23     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 24     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 25          |Argentina|Capital Federal|Palermo|Palermo Soho|
# 26                       |Argentina|Capital Federal|Palermo|
# 27     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 28                       |Argentina|Capital Federal|Palermo|
# 29                       |Argentina|Capital Federal|Palermo|
# ...                                                      ...
# 18949           |Argentina|Capital Federal|Villa Pueyrredón|
# 18950           |Argentina|Capital Federal|Villa Pueyrredón|
# 18951           |Argentina|Capital Federal|Villa Pueyrredón|
# 18952                   |Argentina|Capital Federal|Belgrano|
# 18953           |Argentina|Capital Federal|Villa Pueyrredón|
# 18954           |Argentina|Capital Federal|Villa Pueyrredón|
# 18955              |Argentina|Capital Federal|Villa Urquiza|
# 18956                  |Argentina|Capital Federal|Agronomía|
# 18957           |Argentina|Capital Federal|Villa Pueyrredón|
# 18958           |Argentina|Capital Federal|Villa Pueyrredón|
# 18959           |Argentina|Capital Federal|Villa Pueyrredón|
# 18960           |Argentina|Capital Federal|Villa Pueyrredón|
# 18961           |Argentina|Capital Federal|Villa Pueyrredón|
# 18962           |Argentina|Capital Federal|Villa Pueyrredón|
# 18963               |Argentina|Capital Federal|Villa Lugano|
# 18964               |Argentina|Capital Federal|Villa Lugano|
# 18965              |Argentina|Capital Federal|Villa Soldati|
# 18966               |Argentina|Bs.As. G.B.A. Zona Sur|Lanús|
# 18967              |Argentina|Capital Federal|Villa Soldati|
# 18968              |Argentina|Capital Federal|Villa Soldati|
# 18969               |Argentina|Capital Federal|Villa Lugano|
# 18970              |Argentina|Capital Federal|Villa Soldati|
# 18971              |Argentina|Capital Federal|Villa Soldati|
# 18972              |Argentina|Capital Federal|Villa Soldati|
# 18973              |Argentina|Capital Federal|Villa Soldati|
# 18974              |Argentina|Capital Federal|Villa Soldati|
# 18975              |Argentina|Capital Federal|Villa Soldati|
# 18976              |Argentina|Capital Federal|Villa Soldati|
# 18977              |Argentina|Capital Federal|Villa Soldati|
# 18978               |Argentina|Capital Federal|Villa Lugano|
#
#                              lat-lon        lat        lon  price_aprox_usd  \
# 0      -34.5889531469,-58.4298817776 -34.588953 -58.429882       2000000.00
# 1              -34.586069,-58.414431 -34.586069 -58.414431        790000.00
# 2             -34.589723,-58.4325664 -34.589723 -58.432566        343000.00
# 3            -34.5923646,-58.4144028 -34.592365 -58.414403        145000.00
# 4       -34.585652875,-58.4114933233 -34.585653 -58.411493        175000.00
# 5          -34.57582474,-58.43432236 -34.575825 -58.434322        120000.00
# 6            -34.5739059,-58.4391946 -34.573906 -58.439195        100000.00
# 7            -34.5729833,-58.4388579 -34.572983 -58.438858        390000.00
# 8            -34.5956086,-58.4247641 -34.595609 -58.424764        110000.00
# 9            -34.5580305,-58.4170088 -34.558031 -58.417009         50000.00
# 10            -34.589246,-58.4140598 -34.589246 -58.414060        220000.00
# 11            -34.584198,-58.4152675 -34.584198 -58.415268        170000.00
# 12     -34.5841882044,-58.4431635937 -34.584188 -58.443164        360000.00
# 13             -34.577645,-58.433104 -34.577645 -58.433104        219000.00
# 14           -34.5699614,-58.4323397 -34.569961 -58.432340        685000.00
# 15            -34.573524,-58.4405828 -34.573524 -58.440583        248675.00
# 16     -34.5826800135,-58.4287112553 -34.582680 -58.428711        690000.00
# 17           -34.5915484,-58.4258961 -34.591548 -58.425896       1950000.00
# 18      -34.588912403,-58.4134942185 -34.588912 -58.413494        340000.00
# 19           -34.5770327,-58.4233675 -34.577033 -58.423368        222000.00
# 20           -34.5950139,-58.4273915 -34.595014 -58.427392        180000.00
# 21           -34.5817764,-58.4224975 -34.581776 -58.422497        400000.00
# 22           -34.5793535,-58.4364489 -34.579354 -58.436449       1200000.00
# 23           -34.5849148,-58.4372171 -34.584915 -58.437217        290000.00
# 24           -34.5809281,-58.4404321 -34.580928 -58.440432        270000.00
# 25            -34.5897765,-58.428558 -34.589776 -58.428558        219000.00
# 26           -34.5807098,-58.3981425 -34.580710 -58.398143              NaN
# 27           -34.5842942,-58.4364688 -34.584294 -58.436469              NaN
# 28           -34.5711496,-58.4232966 -34.571150 -58.423297              NaN
# 29            -34.594251,-58.4166447 -34.594251 -58.416645        250000.00
# ...                              ...        ...        ...              ...
# 18949          -34.574804,-58.511286 -34.574804 -58.511286        115000.00
# 18950          -34.582382,-58.493928 -34.582382 -58.493928        120000.00
# 18951        -34.5828265,-58.4965192 -34.582827 -58.496519         70000.00
# 18952         -34.577302,-58.5084239 -34.577302 -58.508424        158840.00
# 18953        -34.5814759,-58.5055408 -34.581476 -58.505541        187000.00
# 18954        -34.5844982,-58.5058017 -34.584498 -58.505802        145000.00
# 18955  -34.5869610349,-58.4991220286 -34.586961 -58.499122        145000.00
# 18956  -34.5857925673,-58.4991678032 -34.585793 -58.499168        145000.00
# 18957  -34.5916666575,-58.5017040921 -34.591667 -58.501704        291000.00
# 18958         -34.576294,-58.5059185 -34.576294 -58.505919        110000.00
# 18959            -34.5848,-58.490567 -34.584800 -58.490567        289900.00
# 18960          -34.582448,-58.507942 -34.582448 -58.507942        115000.00
# 18961        -34.5829089,-58.4928668 -34.582909 -58.492867        448000.00
# 18962        -34.5861739,-58.5063677 -34.586174 -58.506368        148500.00
# 18963          -34.662435,-58.466795 -34.662435 -58.466795         88000.00
# 18964        -34.6650164,-58.4431386 -34.665016 -58.443139         50000.00
# 18965        -34.6579271,-58.4327115 -34.657927 -58.432712        105000.00
# 18966        -34.6651916,-58.4393973 -34.665192 -58.439397         90000.00
# 18967        -34.6601955,-58.4489907 -34.660196 -58.448991        124000.00
# 18968          -34.6633106,-58.43915 -34.663311 -58.439150         90000.00
# 18969        -34.6640573,-58.4443398 -34.664057 -58.444340        115000.00
# 18970          -34.669288,-58.443725 -34.669288 -58.443725         50000.00
# 18971          -34.669535,-58.444304 -34.669535 -58.444304         49900.00
# 18972  -34.6660551661,-58.4419339087 -34.666055 -58.441934         50000.00
# 18973           -34.66897,-58.443897 -34.668970 -58.443897         49000.00
# 18974          -34.668741,-58.443146 -34.668741 -58.443146         60000.00
# 18975           -34.66417,-58.443317 -34.664170 -58.443317         99000.00
# 18976         -34.6618136,-58.426504 -34.661814 -58.426504       3300000.00
# 18977          -34.665005,-58.443041 -34.665005 -58.443041         50433.01
# 18978          -34.664283,-58.469604 -34.664283 -58.469604         75000.00
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  floor  \
# 0                    312.0                    NaN       6410.256410    NaN
# 1                    121.0                  121.0       6528.925620    NaN
# 2                    122.0                  108.0       2811.475410    NaN
# 3                     24.0                   24.0       6041.666667    NaN
# 4                     24.0                   24.0       7291.666667    NaN
# 5                     30.0                   30.0       4000.000000    1.0
# 6                     26.0                    NaN       3846.153846    NaN
# 7                     57.0                   57.0       6842.105263    NaN
# 8                     48.0                   48.0       2291.666667    NaN
# 9                     20.0                   20.0       2500.000000    NaN
# 10                    31.0                   31.0       7096.774194    NaN
# 11                    70.0                   70.0       2428.571429    NaN
# 12                   193.0                  176.0       1865.284974    NaN
# 13                    84.0                   84.0       2607.142857    NaN
# 14                   185.0                  185.0       3702.702703    NaN
# 15                    76.0                   76.0       3272.039474    NaN
# 16                    70.0                   70.0       9857.142857    NaN
# 17                   341.0                    NaN       5718.475073    NaN
# 18                   130.0                  120.0       2615.384615    NaN
# 19                    52.0                   48.0       4269.230769    NaN
# 20                    70.0                   70.0       2571.428571    NaN
# 21                   130.0                  130.0       3076.923077    NaN
# 22                   532.0                  334.0       2255.639098    NaN
# 23                    50.0                   50.0       5800.000000    NaN
# 24                    67.0                   64.0       4029.850746    NaN
# 25                    72.0                    NaN       3041.666667    NaN
# 26                   238.0                  238.0               NaN    NaN
# 27                   475.0                  400.0               NaN    NaN
# 28                   475.0                  400.0               NaN    NaN
# 29                    67.0                   60.0       3731.343284    NaN
# ...                    ...                    ...               ...    ...
# 18949                 62.0                   56.0       1854.838710    3.0
# 18950                130.0                   65.0        923.076923    NaN
# 18951                  NaN                   66.0               NaN    NaN
# 18952                102.0                   72.0       1557.254902    NaN
# 18953                 98.0                   90.0       1908.163265    NaN
# 18954                 50.0                   40.0       2900.000000    NaN
# 18955                 55.0                   52.0       2636.363636    NaN
# 18956                 55.0                   52.0       2636.363636    NaN
# 18957                201.0                   80.0       1447.761194    NaN
# 18958                  NaN                    NaN               NaN    NaN
# 18959                180.0                  180.0       1610.555556    NaN
# 18960                 50.0                   50.0       2300.000000    6.0
# 18961                260.0                    NaN       1723.076923    NaN
# 18962                 60.0                    NaN       2475.000000    NaN
# 18963                 55.0                   55.0       1600.000000    NaN
# 18964                 70.0                   70.0        714.285714    NaN
# 18965                  NaN                    NaN               NaN    NaN
# 18966                  NaN                    NaN               NaN    NaN
# 18967                160.0                  120.0        775.000000    NaN
# 18968                  NaN                   60.0               NaN    NaN
# 18969                120.0                  100.0        958.333333    NaN
# 18970                 75.0                   75.0        666.666667    NaN
# 18971                 75.0                   75.0        665.333333    NaN
# 18972                 72.0                   72.0        694.444444    7.0
# 18973                 75.0                   75.0        653.333333    NaN
# 18974                 55.0                   55.0       1090.909091    NaN
# 18975                115.0                   82.0        860.869565    NaN
# 18976                  NaN                 4162.0               NaN    NaN
# 18977                 45.0                   45.0       1120.733556    NaN
# 18978                 60.0                   58.0       1250.000000    9.0
#
#        rooms  expenses  \
# 0        NaN       NaN
# 1        NaN       NaN
# 2        2.0       NaN
# 3        NaN       NaN
# 4        NaN       NaN
# 5        NaN       NaN
# 6        NaN       NaN
# 7        NaN       NaN
# 8        NaN       NaN
# 9        NaN       NaN
# 10       1.0    1045.0
# 11       NaN    2800.0
# 12       NaN       NaN
# 13       NaN       NaN
# 14       NaN       NaN
# 15       NaN       NaN
# 16       NaN       NaN
# 17       NaN       NaN
# 18       4.0    8000.0
# 19       1.0       NaN
# 20       NaN    3000.0
# 21       NaN       NaN
# 22       6.0       NaN
# 23       NaN       NaN
# 24       3.0    3900.0
# 25       3.0       NaN
# 26       5.0       NaN
# 27       NaN       NaN
# 28       NaN       NaN
# 29       2.0       NaN
# ...      ...       ...
# 18949    3.0       NaN
# 18950    3.0       NaN
# 18951    NaN    2900.0
# 18952    NaN       NaN
# 18953    3.0       NaN
# 18954    2.0       NaN
# 18955    3.0       NaN
# 18956    3.0       NaN
# 18957    3.0       NaN
# 18958    NaN       NaN
# 18959    4.0       NaN
# 18960    2.0       NaN
# 18961    4.0       NaN
# 18962    2.0       NaN
# 18963    3.0       NaN
# 18964    4.0       NaN
# 18965    NaN       NaN
# 18966    NaN       NaN
# 18967    NaN       NaN
# 18968    NaN       NaN
# 18969    3.0       NaN
# 18970    4.0       NaN
# 18971    4.0       NaN
# 18972    4.0       NaN
# 18973    4.0       NaN
# 18974    3.0       NaN
# 18975    3.0       NaN
# 18976    NaN       NaN
# 18977    3.0       NaN
# 18978    3.0       NaN
#
#                                                                                                                                                                                                                       properati_url  \
# 0                                                                                                                                                                 https://www.properati.com.ar/2os_venta_casa_palermo-viejo_rent-ba
# 1                                                                                                         https://www.properati.com.ar/1cl7l_venta_local_palermo_santa-fe-av-al-3500_sotano_garage_subte-linea-d_deptos-temporarios
# 2                                                                                    https://www.properati.com.ar/1cm8w_venta_local_palermo-soho_cabrera-jose-a-_5000_jardin_lavadero_patio_piscina_toilette_garage_ojo-propiedades
# 3                                                                                                        https://www.properati.com.ar/1covk_venta_local_palermo_paraguay-al-3500_subte-linea-d_brick-propiedades-local-alto-palermo
# 4                                                                                                                                            https://www.properati.com.ar/1csk7_venta_local_barrio-norte_subte-linea-d_aranalfe_e1j
# 5                                                                                                            https://www.properati.com.ar/1cw7a_venta_local_palermo_av-santa-fe_5300_garage_subte-linea-d_solucion-inmobiliaria_gx3
# 6                                                                                      https://www.properati.com.ar/1d36i_venta_local_belgrano_dumont-santos_2400_luminoso_impecable_subte-linea-d_urbana-consultores-inmobiliarios
# 7                                                                                                           https://www.properati.com.ar/1d3k8_venta_local_palermo_cabildo-av-_200_garage_estrenar_subte-linea-d_triada-propiedades
# 8                                                                                                                                                       https://www.properati.com.ar/1d5sl_venta_local_palermo_zappone-inmobiliaria
# 9                                                                                                                          https://www.properati.com.ar/1d86m_venta_local_palermo_santa-fe-av-_4400_subte-linea-d_gaed-inmobiliaria
# 10                                                                                                                                          https://www.properati.com.ar/1d8mr_venta_local_palermo_impecable_geraci-propiedades_gkz
# 11                                                                                                        https://www.properati.com.ar/1dcnv_venta_local_barrio-norte_arenales_3800_subte-linea-d_zuker-servicios-inmobiliarios_gsp
# 12                                                                                                              https://www.properati.com.ar/1dd77_venta_local_palermo-hollywood_balcon_lavadero_terraza_metro-estudio-inmobiliario
# 13                                                                                                                                        https://www.properati.com.ar/1di5h_venta_local_palermo_subte-linea-d_re-max-ra-iacute-ces
# 14                                                                                                                   https://www.properati.com.ar/1dv8b_venta_local_belgrano_subte-linea-d_maxi-totah-operaciones-inmobiliarias_e2l
# 15                                                                                                              https://www.properati.com.ar/1dw79_venta_local_palermo_matienzo-benjamin-2489_subte-linea-d_aguero-vera-propiedades
# 16                                                                                                                                           https://www.properati.com.ar/1dygl_venta_local_palermo_estrenar_subte-linea-d_ew-group
# 17                                                                                                                            https://www.properati.com.ar/1dyx2_venta_local_palermo_scalabrini-ortiz-raul-av-_1500_global-property
# 18          https://www.properati.com.ar/1dzv6_venta_departamento_palermo_guemes_3600_balcon_suite_jardin_lavadero_luminoso_lujoso_dependencias_placard_doble-circulacion_subte-linea-d_luisio-propiedades-suc-virrey-del-pino-2378
# 19                                     https://www.properati.com.ar/1e05k_venta_departamento_palermo_juncal-al-4500_gimnasio_jardin_lavadero_parrilla_piscina_sum_aire-acondicionado_subte-linea-h_subte-linea-c_deptos-temporarios
# 20                                                                                               https://www.properati.com.ar/1e0mq_venta_departamento_palermo_julian-alvarez-al-1200_lavadero_amoblado_sanchez-carrizo-real-estate
# 21                                                                                                                                      https://www.properati.com.ar/1e1lu_venta_local_palermo_thames_2400_subte-linea-d_de-locales
# 22                                                                                               https://www.properati.com.ar/1e1ve_venta_casa_palermo-hollywood_jardin_lavadero_piscina_luminoso_vista_garage_nexo-propiedades_h0z
# 23                                                                                                                                   https://www.properati.com.ar/1e1wo_venta_local_palermo-hollywood_luminoso_nexo-propiedades_h0z
# 24                                                                              https://www.properati.com.ar/1e1x0_venta_departamento_palermo-hollywood_arevalo_1700_balcon_toilette_luminoso_apto-credito-hipotecario_yankel-group
# 25                                                                                                                            https://www.properati.com.ar/1e1xj_venta_ph_palermo-soho_honduras_4800_patio_luminoso_ojo-propiedades
# 26                                                                     https://www.properati.com.ar/1e2js_venta_departamento_palermo_baulera_suite_luminoso_dependencias_garage_amenities_subte-linea-h_abp-consultora-inmobiliaria
# 27     https://www.properati.com.ar/1e2l8_venta_casa_palermo-hollywood_balcon_suite_gimnasio_hidromasaje_jardin_lavadero_parrilla_patio_quincho_terraza_vestidor_luminoso_sauna_garage_aire-acondicionado_quicksale-propiedades_e0i
# 28               https://www.properati.com.ar/1e2ll_venta_casa_palermo_balcon_suite_gimnasio_hidromasaje_jardin_lavadero_parrilla_patio_quincho_terraza_vestidor_luminoso_sauna_garage_aire-acondicionado_quicksale-propiedades_e0i
# 29                                                                  https://www.properati.com.ar/1e2mz_venta_departamento_palermo_balcon_lavadero_parrilla_piscina_aire-acondicionado_apto-credito-hipotecario_ageo-propiedades_dwr
# ...                                                                                                                                                                                                                             ...
# 18949                                                                                                                 https://www.properati.com.ar/1k3zz_venta_departamento_villa-pueyrredon_balcon_luminoso_placard_re-max-avenida
# 18950                                                                                                 https://www.properati.com.ar/1k401_venta_ph_villa-pueyrredon_suite_lavadero_terraza_toilette_vestidor_luminoso_re-max-avenida
# 18951                                                                                                                        https://www.properati.com.ar/1k4is_venta_local_villa-pueyrredon_grupo-mega-villapueyrredon-mosconi2403
# 18952                                                                                 https://www.properati.com.ar/1k4jj_venta_casa_velez-sarsfield_balcon_suite_terraza_toilette_garage_aire-acondicionado_century-21-republicador
# 18953                                                                                      https://www.properati.com.ar/1k4n1_venta_ph_villa-pueyrredon_lavadero_patio_terraza_garage_apto-credito-hipotecario_roma-propiedades_hzx
# 18954                                                   https://www.properati.com.ar/1k4pv_venta_ph_villa-pueyrredon_balcon_baulera_parrilla_luminoso_garage_aire-acondicionado_apto-credito-hipotecario_bienvende-amelia-claro_e77
# 18955                                                                                                                            https://www.properati.com.ar/1k4up_venta_departamento_villa-urquiza_riveros-negocios-inmobiliarios
# 18956                                                                                                                                https://www.properati.com.ar/1k4uq_venta_departamento_agronomia_riveros-negocios-inmobiliarios
# 18957                                                                                  https://www.properati.com.ar/1k6fh_venta_ph_villa-pueyrredon_balcon_lavadero_parrilla_terraza_vestidor_amoblado_placard_like-propiedades_dvy
# 18958                                                                                         https://www.properati.com.ar/1k76a_venta_departamento_villa-pueyrredon_balcon_placard_apto-credito-hipotecario_duarte-propiedades_epx
# 18959                                                 https://www.properati.com.ar/1k7w1_venta_ph_villa-pueyrredon_lavadero_parrilla_patio_quincho_terraza_luminoso_amoblado_impecable_placard_aire-acondicionado_re-max-premium-ii
# 18960                                                                                                                          https://www.properati.com.ar/1kb1t_venta_departamento_villa-pueyrredon_luminoso_placard_re-max-lagos
# 18961                                                                                                     https://www.properati.com.ar/1kelk_venta_casa_villa-pueyrredon_lavadero_parrilla_patio_terraza_garage_rcm-propiedades_c67
# 18962                                                                             https://www.properati.com.ar/1kem4_venta_ph_villa-pueyrredon_parrilla_patio_terraza_luminoso_placard_apto-credito-hipotecario_rcm-propiedades_c67
# 18963                                                                      https://www.properati.com.ar/1fakt_venta_departamento_villa-lugano_balcon_luminoso_garage_impecable_apto-credito-hipotecario_gabriel-torres-inmobiliaria
# 18964                                                                                                    https://www.properati.com.ar/1fnpn_venta_departamento_villa-lugano_balcon_luminoso_subte-premetro_dalle-nogare-propiedades
# 18965                                                                           https://www.properati.com.ar/1glpm_venta_casa_monte-chingolo_suite_jardin_lavadero_parrilla_patio_quincho_vestidor_garage_placard_novo-inmobiliaria
# 18966                                                                                                         https://www.properati.com.ar/1goie_venta_casa_lanus_lavadero_patio_subte-premetro_insaurralde-servicios-inmobiliarios
# 18967                                                           https://www.properati.com.ar/1grdk_venta_ph_villa-soldati_gimnasio_lavadero_parrilla_quincho_terraza_toilette_luminoso_impecable_subte-premetro_mb-inmobiliaria-s-a
# 18968                                                                             https://www.properati.com.ar/1hbft_venta_departamento_villa-soldati_balcon_lavadero_quincho_luminoso_subte-premetro_sanchez-chiliotti-propiedades
# 18969                                                                                                                   https://www.properati.com.ar/1hbhx_venta_casa_villa-lugano_subte-premetro_patricia-robutti-sucursal-guamini
# 18970                                                                                                              https://www.properati.com.ar/1hlfv_venta_departamento_villa-soldati_balcon_lavadero_subte-premetro_re-max-parque
# 18971                                                                                                                              https://www.properati.com.ar/1hlg3_venta_departamento_villa-soldati_subte-premetro_re-max-parque
# 18972                                                                                       https://www.properati.com.ar/1ie0c_venta_departamento_villa-soldati_acosta-mariano_3495_lavadero_luminoso_subte-premetro_re-max-avenida
# 18973                                                                                                                                             https://www.properati.com.ar/1j22x_venta_departamento_villa-soldati_re-max-parque
# 18974                                                                                                           https://www.properati.com.ar/1jcpm_venta_departamento_villa-soldati_roca-cnel-av-_3500_subte-premetro_re-max-parque
# 18975                                                                                      https://www.properati.com.ar/1k1hs_venta_casa_villa-soldati_lavadero_parrilla_terraza_garage_placard_subte-premetro_re-max-acci-oacute-n
# 18976                                                                                                        https://www.properati.com.ar/1k1mv_venta_local_villa-soldati_aire-acondicionado_ana-simeone-inmuebles-corporativos_9ia
# 18977                                                                                                                      https://www.properati.com.ar/1k5v0_venta_departamento_villa-soldati_lavadero_subte-premetro_re-max-ayres
# 18978                                                                                                                       https://www.properati.com.ar/1k5x2_venta_departamento_villa-lugano_balcon_lavadero_sum_re-max-accion-ii
#
#                  barrio  comuna
# 0               PALERMO    14.0
# 1               PALERMO    14.0
# 2               PALERMO    14.0
# 3               PALERMO    14.0
# 4               PALERMO    14.0
# 5               PALERMO    14.0
# 6               PALERMO    14.0
# 7               PALERMO    14.0
# 8               PALERMO    14.0
# 9               PALERMO    14.0
# 10              PALERMO    14.0
# 11              PALERMO    14.0
# 12              PALERMO    14.0
# 13              PALERMO    14.0
# 14              PALERMO    14.0
# 15              PALERMO    14.0
# 16              PALERMO    14.0
# 17              PALERMO    14.0
# 18              PALERMO    14.0
# 19              PALERMO    14.0
# 20              PALERMO    14.0
# 21              PALERMO    14.0
# 22              PALERMO    14.0
# 23              PALERMO    14.0
# 24              PALERMO    14.0
# 25              PALERMO    14.0
# 26              PALERMO    14.0
# 27              PALERMO    14.0
# 28              PALERMO    14.0
# 29              PALERMO    14.0
# ...                 ...     ...
# 18949  VILLA PUEYRREDON    12.0
# 18950  VILLA PUEYRREDON    12.0
# 18951  VILLA PUEYRREDON    12.0
# 18952  VILLA PUEYRREDON    12.0
# 18953  VILLA PUEYRREDON    12.0
# 18954  VILLA PUEYRREDON    12.0
# 18955  VILLA PUEYRREDON    12.0
# 18956  VILLA PUEYRREDON    12.0
# 18957  VILLA PUEYRREDON    12.0
# 18958  VILLA PUEYRREDON    12.0
# 18959  VILLA PUEYRREDON    12.0
# 18960  VILLA PUEYRREDON    12.0
# 18961  VILLA PUEYRREDON    12.0
# 18962  VILLA PUEYRREDON    12.0
# 18963     VILLA SOLDATI     8.0
# 18964     VILLA SOLDATI     8.0
# 18965     VILLA SOLDATI     8.0
# 18966     VILLA SOLDATI     8.0
# 18967     VILLA SOLDATI     8.0
# 18968     VILLA SOLDATI     8.0
# 18969     VILLA SOLDATI     8.0
# 18970     VILLA SOLDATI     8.0
# 18971     VILLA SOLDATI     8.0
# 18972     VILLA SOLDATI     8.0
# 18973     VILLA SOLDATI     8.0
# 18974     VILLA SOLDATI     8.0
# 18975     VILLA SOLDATI     8.0
# 18976     VILLA SOLDATI     8.0
# 18977     VILLA SOLDATI     8.0
# 18978     VILLA SOLDATI     8.0
#
# [18979 rows x 17 columns]

# %% [markdown]
# ## Exploración de datos

# %% [markdown]
# Lo primero que vamos a hacer es ver qué forma tiene el dataset que acabamos de cargar. Para eso vamos a mostrar las primeras 3 entradas del mismo y utilizar la propiedad `shape` para ver la cantidad de instancias y atributos con los que vamos a estar trabajando.

# %%
print(df.shape)
df.head(3)
# Out:
# (18979, 17)
#    created_on operation property_type  \
# 0  2017-09-22      sell         house
# 1  2017-08-01      sell         store
# 2  2017-08-02      sell         store
#
#                              place_with_parent_names  \
# 0  |Argentina|Capital Federal|Palermo|Palermo Viejo|
# 1                |Argentina|Capital Federal|Palermo|
# 2   |Argentina|Capital Federal|Palermo|Palermo Soho|
#
#                          lat-lon        lat        lon  price_aprox_usd  \
# 0  -34.5889531469,-58.4298817776 -34.588953 -58.429882        2000000.0
# 1          -34.586069,-58.414431 -34.586069 -58.414431         790000.0
# 2         -34.589723,-58.4325664 -34.589723 -58.432566         343000.0
#
#    surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  floor  rooms  \
# 0                312.0                    NaN        6410.25641    NaN    NaN
# 1                121.0                  121.0        6528.92562    NaN    NaN
# 2                122.0                  108.0        2811.47541    NaN    2.0
#
#    expenses  \
# 0       NaN
# 1       NaN
# 2       NaN
#
#                                                                                                                                     properati_url  \
# 0                                                                               https://www.properati.com.ar/2os_venta_casa_palermo-viejo_rent-ba
# 1                       https://www.properati.com.ar/1cl7l_venta_local_palermo_santa-fe-av-al-3500_sotano_garage_subte-linea-d_deptos-temporarios
# 2  https://www.properati.com.ar/1cm8w_venta_local_palermo-soho_cabrera-jose-a-_5000_jardin_lavadero_patio_piscina_toilette_garage_ojo-propiedades
#
#     barrio  comuna
# 0  PALERMO    14.0
# 1  PALERMO    14.0
# 2  PALERMO    14.0

# %% [markdown]
# ## Categorías de propiedades
# En primer lugar vamos a ver qué categorías existen en el campo `property_type`. Y de esas categorías cuantos valores tenemos de cada uno.
#
# **3) Mostrá** las categorías de `property_type` y cuántas instancias hay de cada una.
#
# Recordá utilizar funciones del **dataframe** de pandas para realizar esto.

# %%
# mostrá las categorías del campo property_type y mostrá la cant. de valores en esta celda
pt = pd.DataFrame(df['property_type'])
index = pd.Index(pt)
index.value_counts()
# Out:
# (apartment,)    14807
# (house,)         1618
# (PH,)            1463
# (store,)         1091
# dtype: int64

# %% [markdown]
# ### Filtrando las categorías
#
# De las categorías existentes sólo queremos quedarnos con las que sean casas (house), departamentos (apartment) o PH (PH).
#
# Para esto,
#
# **4) filtrá** el `dataframe` original creando un **nuevo** `dataframe` llamado `df_filtered`. Este es el `dataframe` que seguirás usando a lo largo del análisis.

# %%
# Filtrá el dataframe en esta celda
df_filtered = pd.DataFrame(df)

# %% [markdown]
# ### Visualizando las categorías
# **5)** Utilizando `seaborn` **creá un countplot** para visualizar las categorías de `df_filtered` en el campo `property_type`

# %%
# Visualizá las categorías en esta celda
#prop = sns.load_dataset(df_filtered['property_type'])
cppt = sns.countplot(x="property_type", hue="property_type", palette="Set3", data=pd.DataFrame(df_filtered['property_type']))

# %% [markdown]
# ## Valores Faltantes

# %% [markdown]
# Vamos a querer descartar aquellas instancias que tengan valores nulos en columnas importantes para el análisis del mercado.
# Estas columnas son las que informan **superficie (total o cubierta)**, **cantidad de ambientes**, **precio** y **precio por metro cuadrado**.
#
# **6) Quitá** del `dataframe` las instancias que no tengan ningún valor en los campos nombrados.

# %%
# Quitá las instancias con valores nules en esta celda
df_filtered.dropna()
# Out:
#        created_on operation property_type  \
# 137    2017-09-10      sell     apartment
# 140    2017-09-10      sell     apartment
# 176    2017-09-13      sell     apartment
# 177    2017-09-13      sell     apartment
# 180    2017-09-13      sell     apartment
# 181    2017-09-13      sell     apartment
# 433    2017-10-04      sell     apartment
# 511    2017-10-11      sell     apartment
# 731    2017-10-21      sell     apartment
# 732    2017-10-21      sell     apartment
# 733    2017-10-21      sell     apartment
# 915    2017-11-04      sell     apartment
# 987    2017-11-09      sell     apartment
# 1332   2017-12-05      sell     apartment
# 1394   2017-12-06      sell     apartment
# 1396   2017-12-06      sell     apartment
# 1397   2017-12-06      sell     apartment
# 1483   2017-12-13      sell     apartment
# 1484   2017-12-13      sell     apartment
# 1769   2018-01-18      sell     apartment
# 1780   2018-01-18      sell     apartment
# 1781   2018-01-18      sell     apartment
# 1782   2018-01-18      sell     apartment
# 2138   2018-01-24      sell     apartment
# 2293   2018-01-31      sell     apartment
# 2297   2018-01-31      sell     apartment
# 2298   2018-01-31      sell     apartment
# 2322   2018-01-31      sell            PH
# 2334   2018-01-31      sell     apartment
# 2335   2018-01-31      sell     apartment
# ...           ...       ...           ...
# 16380  2018-01-18      sell     apartment
# 16657  2018-01-31      sell     apartment
# 16720  2017-10-27      sell     apartment
# 16839  2018-01-31      sell     apartment
# 16920  2017-12-06      sell     apartment
# 17010  2017-10-11      sell     apartment
# 17610  2018-01-28      sell     apartment
# 17611  2018-01-28      sell            PH
# 17618  2018-01-31      sell     apartment
# 17620  2018-01-31      sell     apartment
# 17622  2018-01-31      sell     apartment
# 17623  2018-01-31      sell     apartment
# 17799  2017-10-11      sell     apartment
# 17889  2017-11-16      sell     apartment
# 17940  2018-01-18      sell     apartment
# 18000  2018-01-31      sell     apartment
# 18059  2017-09-10      sell     apartment
# 18227  2018-01-31      sell     apartment
# 18252  2017-10-21      sell     apartment
# 18412  2018-01-18      sell     apartment
# 18413  2018-01-18      sell     apartment
# 18422  2018-01-28      sell     apartment
# 18424  2018-01-31      sell     apartment
# 18495  2017-10-27      sell            PH
# 18621  2018-01-18      sell     apartment
# 18657  2018-01-31      sell     apartment
# 18665  2018-01-31      sell     apartment
# 18716  2017-10-27      sell     apartment
# 18717  2017-11-02      sell     apartment
# 18729  2017-11-28      sell     apartment
#
#                                      place_with_parent_names  \
# 137                     |Argentina|Capital Federal|Belgrano|
# 140    |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 176                     |Argentina|Capital Federal|Belgrano|
# 177                     |Argentina|Capital Federal|Belgrano|
# 180                      |Argentina|Capital Federal|Palermo|
# 181    |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 433                     |Argentina|Capital Federal|Belgrano|
# 511                      |Argentina|Capital Federal|Palermo|
# 731        |Argentina|Capital Federal|Palermo|Palermo Chico|
# 732                      |Argentina|Capital Federal|Palermo|
# 733    |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 915        |Argentina|Capital Federal|Palermo|Palermo Chico|
# 987                      |Argentina|Capital Federal|Palermo|
# 1332                    |Argentina|Capital Federal|Belgrano|
# 1394                    |Argentina|Capital Federal|Belgrano|
# 1396   |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 1397                     |Argentina|Capital Federal|Palermo|
# 1483   |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 1484                    |Argentina|Capital Federal|Belgrano|
# 1769                     |Argentina|Capital Federal|Palermo|
# 1780   |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 1781                     |Argentina|Capital Federal|Palermo|
# 1782   |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 2138                     |Argentina|Capital Federal|Palermo|
# 2293       |Argentina|Capital Federal|Palermo|Palermo Chico|
# 2297                    |Argentina|Capital Federal|Recoleta|
# 2298                    |Argentina|Capital Federal|Belgrano|
# 2322       |Argentina|Capital Federal|Palermo|Palermo Chico|
# 2334                |Argentina|Capital Federal|Barrio Norte|
# 2335                     |Argentina|Capital Federal|Palermo|
# ...                                                      ...
# 16380                   |Argentina|Capital Federal|Saavedra|
# 16657                      |Argentina|Capital Federal|Boedo|
# 16720                 |Argentina|Capital Federal|Colegiales|
# 16839                 |Argentina|Capital Federal|Colegiales|
# 16920                   |Argentina|Capital Federal|Belgrano|
# 17010               |Argentina|Capital Federal|Monte Castro|
# 17610               |Argentina|Capital Federal|Villa Lugano|
# 17611               |Argentina|Capital Federal|Villa Lugano|
# 17618               |Argentina|Capital Federal|Villa Lugano|
# 17620               |Argentina|Capital Federal|Villa Lugano|
# 17622               |Argentina|Capital Federal|Villa Lugano|
# 17623               |Argentina|Capital Federal|Villa Lugano|
# 17799                  |Argentina|Capital Federal|San Telmo|
# 17889                  |Argentina|Capital Federal|San Telmo|
# 17940                  |Argentina|Capital Federal|San Telmo|
# 18000                  |Argentina|Capital Federal|San Telmo|
# 18059                   |Argentina|Capital Federal|Belgrano|
# 18227              |Argentina|Capital Federal|Villa Urquiza|
# 18252              |Argentina|Capital Federal|Villa Urquiza|
# 18412           |Argentina|Capital Federal|Parque Chacabuco|
# 18413           |Argentina|Capital Federal|Parque Chacabuco|
# 18422           |Argentina|Capital Federal|Parque Chacabuco|
# 18424           |Argentina|Capital Federal|Parque Chacabuco|
# 18495           |Argentina|Capital Federal|Villa del Parque|
# 18621           |Argentina|Capital Federal|Villa del Parque|
# 18657           |Argentina|Capital Federal|Villa del Parque|
# 18665           |Argentina|Capital Federal|Villa del Parque|
# 18716                    |Argentina|Capital Federal|Coghlan|
# 18717                    |Argentina|Capital Federal|Coghlan|
# 18729                   |Argentina|Capital Federal|Belgrano|
#
#                              lat-lon        lat        lon  price_aprox_usd  \
# 137          -34.5708522,-58.4411794 -34.570852 -58.441179         270000.0
# 140          -34.5832058,-58.4334675 -34.583206 -58.433468         123000.0
# 176          -34.5630665,-58.4383467 -34.563066 -58.438347         268000.0
# 177          -34.5630665,-58.4383467 -34.563066 -58.438347         268000.0
# 180          -34.5808658,-58.4384065 -34.580866 -58.438406         312000.0
# 181          -34.5772535,-58.4344262 -34.577253 -58.434426         312000.0
# 433           -34.568856,-58.4470661 -34.568856 -58.447066         120000.0
# 511          -34.5863377,-58.4201762 -34.586338 -58.420176         230000.0
# 731          -34.5749864,-58.4206108 -34.574986 -58.420611         435000.0
# 732     -34.5757047033,-58.434499746 -34.575705 -58.434500         191000.0
# 733           -34.5756517,-58.434371 -34.575652 -58.434371         191000.0
# 915          -34.5777804,-58.4124673 -34.577780 -58.412467         598000.0
# 987          -34.5870736,-58.4247385 -34.587074 -58.424738         110000.0
# 1332         -34.5657804,-58.4399182 -34.565780 -58.439918         249000.0
# 1394         -34.5736463,-58.4362917 -34.573646 -58.436292         185000.0
# 1396   -34.5770920842,-58.4374199842 -34.577092 -58.437420         205000.0
# 1397           -34.57716,-58.4374671 -34.577160 -58.437467         205000.0
# 1483         -34.5775405,-58.4342597 -34.577541 -58.434260         420000.0
# 1484          -34.567908,-58.4359167 -34.567908 -58.435917         359000.0
# 1769          -34.579422,-58.4082731 -34.579422 -58.408273         168000.0
# 1780          -34.577266,-58.4360803 -34.577266 -58.436080         145000.0
# 1781      -34.5772594,-58.4300490558 -34.577259 -58.430049         148000.0
# 1782         -34.5772594,-58.4301027 -34.577259 -58.430103         148000.0
# 2138   -34.5852473169,-58.4162914668 -34.585247 -58.416291         173000.0
# 2293   -34.5773326251,-58.4069224056 -34.577333 -58.406922         760000.0
# 2297   -34.5873075435,-58.4109480193 -34.587308 -58.410948         274000.0
# 2298    -34.572860247,-58.4396162589 -34.572860 -58.439616         460000.0
# 2322         -34.5744693,-58.4230925 -34.574469 -58.423093         900000.0
# 2334         -34.5877672,-58.4181198 -34.587767 -58.418120         380000.0
# 2335         -34.5844942,-58.4278589 -34.584494 -58.427859         217000.0
# ...                              ...        ...        ...              ...
# 16380  -34.5531880127,-58.4886643185 -34.553188 -58.488664         128000.0
# 16657        -34.6345841,-58.4127622 -34.634584 -58.412762         138000.0
# 16720           -34.58159,-58.449259 -34.581590 -58.449259          75000.0
# 16839         -34.580325,-58.4541032 -34.580325 -58.454103         130000.0
# 16920  -34.6264994359,-58.3595912946 -34.626499 -58.359591         950000.0
# 17010        -34.6137439,-58.4963299 -34.613744 -58.496330          83000.0
# 17610  -34.6800572768,-58.4771555729 -34.680057 -58.477156         125000.0
# 17611        -34.6756979,-58.4759915 -34.675698 -58.475992         110000.0
# 17618        -34.6801744,-58.4771775 -34.680174 -58.477178         120000.0
# 17620          -34.682933,-58.477114 -34.682933 -58.477114         125000.0
# 17622  -34.6759218898,-58.4738176955 -34.675922 -58.473818         100000.0
# 17623        -34.6782525,-58.4767615 -34.678252 -58.476762         360000.0
# 17799  -34.6242338518,-58.3696425131 -34.624234 -58.369643          90000.0
# 17889        -34.6206226,-58.3684327 -34.620623 -58.368433         155000.0
# 17940        -34.6206226,-58.3684327 -34.620623 -58.368433         295000.0
# 18000        -34.6206226,-58.3684327 -34.620623 -58.368433         279000.0
# 18059        -34.5753615,-58.4632282 -34.575361 -58.463228         273000.0
# 18227        -34.5788289,-58.4707077 -34.578829 -58.470708         206000.0
# 18252        -34.5834281,-58.4769078 -34.583428 -58.476908         203000.0
# 18412  -34.6410275269,-58.4231710053 -34.641028 -58.423171          98000.0
# 18413  -34.6410275269,-58.4231710053 -34.641028 -58.423171         130000.0
# 18422  -34.6410275269,-58.4231710053 -34.641028 -58.423171          92000.0
# 18424  -34.6410275269,-58.4231710053 -34.641028 -58.423171          96000.0
# 18495        -34.6036287,-58.4950635 -34.603629 -58.495064          80000.0
# 18621           -34.601828,-58.48979 -34.601828 -58.489790         161000.0
# 18657  -34.6049704784,-58.4905132176 -34.604970 -58.490513         152000.0
# 18665        -34.6048512,-58.4958694 -34.604851 -58.495869         230000.0
# 18716  -34.5613463387,-58.4736814343 -34.561346 -58.473681         178000.0
# 18717         -34.562605,-58.4678472 -34.562605 -58.467847         169000.0
# 18729         -34.559045,-58.4696286 -34.559045 -58.469629         269000.0
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  floor  \
# 137                  185.0                   80.0       1459.459459    1.0
# 140                   32.0                   29.0       3843.750000    3.0
# 176                   82.0                   74.0       3268.292683    7.0
# 177                   84.0                   76.0       3190.476190    7.0
# 180                   98.0                   91.0       3183.673469    2.0
# 181                   98.0                   91.0       3183.673469    2.0
# 433                   39.0                   39.0       3076.923077    6.0
# 511                   89.0                   85.0       2584.269663    6.0
# 731                  100.0                   86.0       4350.000000   10.0
# 732                   92.0                   47.0       2076.086957    3.0
# 733                   92.0                   47.0       2076.086957    3.0
# 915                  118.0                  109.0       5067.796610   14.0
# 987                   36.0                   36.0       3055.555556    5.0
# 1332                  74.0                   74.0       3364.864865   13.0
# 1394                  66.0                   26.0       2803.030303   13.0
# 1396                  68.0                   64.0       3014.705882    4.0
# 1397                  68.0                   64.0       3014.705882    4.0
# 1483                 101.0                   90.0       4158.415842    5.0
# 1484                  99.0                   95.0       3626.262626   13.0
# 1769                  36.0                   36.0       4666.666667    6.0
# 1780                  45.0                   42.0       3222.222222    2.0
# 1781                  53.0                   53.0       2792.452830   11.0
# 1782                  53.0                   53.0       2792.452830   11.0
# 2138                  70.0                   70.0       2471.428571    2.0
# 2293                 187.0                  187.0       4064.171123    4.0
# 2297                 108.0                  108.0       2537.037037    5.0
# 2298                 173.0                  166.0       2658.959538    4.0
# 2322                 255.0                  130.0       3529.411765    1.0
# 2334                 170.0                   76.0       2235.294118    1.0
# 2335                  88.0                   55.0       2465.909091    7.0
# ...                    ...                    ...               ...    ...
# 16380                 56.0                   56.0       2285.714286    1.0
# 16657                 56.0                   56.0       2464.285714    1.0
# 16720                 23.0                   20.0       3260.869565    1.0
# 16839                 43.0                   38.0       3023.255814    6.0
# 16920                305.0                  266.0       3114.754098   16.0
# 17010                 32.0                   28.0       2593.750000    2.0
# 17610                 66.0                   60.0       1893.939394    3.0
# 17611                130.0                   65.0        846.153846    1.0
# 17618                 68.0                   60.0       1764.705882    1.0
# 17620                 62.0                   58.0       2016.129032    2.0
# 17622                 51.0                   51.0       1960.784314    9.0
# 17623                135.0                  120.0       2666.666667    6.0
# 17799                 37.0                   33.0       2432.432432    4.0
# 17889                 48.0                   44.0       3229.166667   11.0
# 17940                100.0                   90.0       2950.000000    5.0
# 18000                100.0                   95.0       2790.000000   10.0
# 18059                105.0                   94.0       2600.000000    6.0
# 18227                 73.0                   66.0       2821.917808    2.0
# 18252                 82.0                   66.0       2475.609756    1.0
# 18412                 49.0                   45.0       2000.000000    7.0
# 18413                 62.0                   58.0       2096.774194    7.0
# 18422                 49.0                   45.0       1877.551020    1.0
# 18424                 46.0                   42.0       2086.956522    7.0
# 18495                 35.0                   35.0       2285.714286    5.0
# 18621                 68.0                   68.0       2367.647059    8.0
# 18657                 79.0                   70.0       1924.050633    3.0
# 18665                 76.0                   69.0       3026.315789    5.0
# 18716                 63.0                   50.0       2825.396825    3.0
# 18717                 63.0                   55.0       2682.539683    1.0
# 18729                109.0                  100.0       2467.889908    2.0
#
#        rooms  expenses  \
# 137      3.0    5400.0
# 140      1.0    2600.0
# 176      3.0    6400.0
# 177      3.0    6400.0
# 180      4.0    9500.0
# 181      4.0    9500.0
# 433      2.0    1200.0
# 511      4.0    4000.0
# 731      3.0    8000.0
# 732      2.0    2050.0
# 733      2.0    2050.0
# 915      4.0    7900.0
# 987      1.0    2100.0
# 1332     4.0    3600.0
# 1394     3.0    2100.0
# 1396     4.0    2800.0
# 1397     4.0    2800.0
# 1483     4.0    4800.0
# 1484     4.0    9800.0
# 1769     2.0    1400.0
# 1780     2.0    1600.0
# 1781     3.0    2200.0
# 1782     3.0    2200.0
# 2138     3.0    2000.0
# 2293     5.0   31084.0
# 2297     4.0    9000.0
# 2298     6.0    4500.0
# 2322     4.0   25000.0
# 2334     4.0    7000.0
# 2335     3.0    2700.0
# ...      ...       ...
# 16380    3.0     700.0
# 16657    3.0    1500.0
# 16720    1.0    1100.0
# 16839    2.0    3000.0
# 16920    4.0   16000.0
# 17010    1.0     700.0
# 17610    3.0       2.0
# 17611    4.0     500.0
# 17618    3.0       2.0
# 17620    3.0    1600.0
# 17622    3.0    1200.0
# 17623    4.0    4000.0
# 17799    1.0    2500.0
# 17889    2.0    2000.0
# 17940    3.0    5000.0
# 18000    3.0    4800.0
# 18059    4.0    4800.0
# 18227    3.0    2000.0
# 18252    3.0    2800.0
# 18412    2.0    1538.0
# 18413    2.0    1911.0
# 18422    2.0    1500.0
# 18424    2.0    1603.0
# 18495    2.0    1200.0
# 18621    2.0    1600.0
# 18657    3.0    2900.0
# 18665    4.0    2900.0
# 18716    2.0    2700.0
# 18717    2.0    1700.0
# 18729    4.0    2900.0
#
#                                                                                                                                                                                                                                                                    properati_url  \
# 137                                                                        https://www.properati.com.ar/1el0x_venta_departamento_belgrano_maure-2324_suite_lavadero_patio_luminoso_lujoso_garage_impecable_losa-radiante_doble-circulacion_subte-linea-d_santiago-jannot-capital
# 140                                                                                              https://www.properati.com.ar/1el2s_venta_departamento_palermo-hollywood_humboldt-al-1900_balcon_parrilla_terraza_luminoso_placard_aire-acondicionado_innovar-grupo-inmobiliario
# 176                                                                                                                          https://www.properati.com.ar/1epbt_venta_departamento_belgrano_lacroze-federico-av-1620_balcon_luminoso_lujoso_dependencias_santiago-jannot-capital
# 177                                                                                                                          https://www.properati.com.ar/1epbu_venta_departamento_belgrano_lacroze-federico-av-1620_balcon_luminoso_lujoso_dependencias_santiago-jannot-capital
# 180                                                                                       https://www.properati.com.ar/1epdp_venta_departamento_palermo_ravignani-emilio-2268_balcon_suite_lavadero_parrilla_piscina_sum_luminoso_lujoso_garage_subte-linea-d_loria-inmobiliaria
# 181                                                                             https://www.properati.com.ar/1epdq_venta_departamento_palermo-hollywood_ravignani-emilio-2268_balcon_suite_lavadero_parrilla_piscina_sum_luminoso_lujoso_garage_subte-linea-d_loria-inmobiliaria
# 433                                                                                                                                                            https://www.properati.com.ar/1fsdy_venta_departamento_belgrano_aguilar-2400_balcon_subte-linea-d_mr-inmuebles_akd
# 511                                                                                                                       https://www.properati.com.ar/1g5kv_venta_departamento_palermo_malabia-2277_balcon_jardin_lavadero_toilette_subte-linea-d_pablo-yaryura-propiedades_bly
# 731                                                                        https://www.properati.com.ar/1hbpm_venta_departamento_palermo-chico_oro-fray-justo-santamaria-de-al-2900_balcon_suite_hidromasaje_piscina_toilette_luminoso_garage_subte-linea-d_bullrich-propiedades
# 732                                                           https://www.properati.com.ar/1hbtd_venta_departamento_palermo_arevalo-2386_balcon_suite_parrilla_patio_luminoso_lujoso_garage_impecable_placard_estrenar_subte-linea-d_apto-credito-hipotecario_loria-inmobiliaria
# 733                                                 https://www.properati.com.ar/1hbte_venta_departamento_palermo-hollywood_arevalo-2386_balcon_suite_parrilla_patio_luminoso_lujoso_garage_impecable_placard_estrenar_subte-linea-d_apto-credito-hipotecario_loria-inmobiliaria
# 915                                                                                         https://www.properati.com.ar/1hrzl_venta_departamento_palermo-chico_segui-juan-f-al-3900_suite_lavadero_toilette_luminoso_vista_dependencias_electrogeno_garage_bullrich-propiedades
# 987                                                                         https://www.properati.com.ar/1hyae_venta_departamento_palermo_soler-al-3200_gimnasio_lavadero_parrilla_piscina_quincho_sum_garage_amenities_subte-linea-d_luciano-cazenave-inversiones-inmobiliarias
# 1332                                                                                                                https://www.properati.com.ar/1imhi_venta_departamento_belgrano_luis-maria-campos-1160_baulera_toilette_luminoso_garage_subte-linea-d_lacroze-propiedades_4pl
# 1394                                                                                                                https://www.properati.com.ar/1irrw_venta_departamento_belgrano_arenal-concepcion-2383_balcon_lavadero_terraza_luminoso_subte-linea-d_lacroze-propiedades_4pl
# 1396                                                                                                                             https://www.properati.com.ar/1iry2_venta_departamento_palermo-hollywood_soler-6076_balcon_lavadero_toilette_luminoso_placard_loria-inmobiliaria
# 1397                                                                                                                         https://www.properati.com.ar/1iry3_venta_departamento_palermo_soler-6076_balcon_lavadero_toilette_luminoso_placard_subte-linea-d_loria-inmobiliaria
# 1483                                                                   https://www.properati.com.ar/1ixic_venta_departamento_palermo-hollywood_balcon_baulera_suite_hidromasaje_lavadero_parrilla_piscina_sum_terraza_lujoso_garage_impecable_losa-radiante_bullrich-propiedades
# 1484                                                                                                                                     https://www.properati.com.ar/1ixid_venta_departamento_belgrano_baulera_suite_lavadero_luminoso_garage_impecable_lacroze-propiedades_4pl
# 1769                                                                                                                                    https://www.properati.com.ar/1jm34_venta_departamento_palermo_balcon_gimnasio_piscina_luminoso_josefina-sackmann-sala-campos-casas-lotes
# 1780                                                                                                                                       https://www.properati.com.ar/1jmge_venta_departamento_palermo-hollywood_balcon_lavadero_luminoso_impecable_placard_loria-inmobiliaria
# 1781                                                                                                                                            https://www.properati.com.ar/1jmgj_venta_departamento_palermo_baulera_lavadero_luminoso_placard_subte-linea-d_loria-inmobiliaria
# 1782                                                                                                                                                https://www.properati.com.ar/1jmgk_venta_departamento_palermo-hollywood_baulera_lavadero_luminoso_placard_loria-inmobiliaria
# 2138                                                                                                                https://www.properati.com.ar/1k2mn_venta_departamento_palermo_scalabrini-ortiz-raul-av-_2500_garage_subte-linea-d_luciano-cazenave-inversiones-inmobiliarias
# 2293                                                                                                        https://www.properati.com.ar/1k99l_venta_departamento_palermo-chico_castex_3500_suite_toilette_vestidor_luminoso_dependencias_electrogeno_innovar-grupo-inmobiliario
# 2297                                                                                                                    https://www.properati.com.ar/1k9df_venta_departamento_recoleta_arenales_3400_luminoso_lujoso_subte-linea-d_astorga-inmobiliaria-federico-prieto-csi-5503
# 2298   https://www.properati.com.ar/1k9ie_venta_departamento_belgrano_cabildo-av-_300_balcon_baulera_lavadero_toilette_garage_aire-acondicionado_subte-linea-d_apto-credito-hipotecario_de-cristobal-servicios-inmobiliarios-m-de-cristobal-csi-5964-j-de-cristobal-cucicba-3304
# 2322                                                                                                                            https://www.properati.com.ar/1kbkn_venta_ph_palermo-chico_balcon_jardin_lavadero_quincho_terraza_dependencias_subte-linea-d_bullrich-propiedades
# 2334                                                                                                                https://www.properati.com.ar/1kc3r_venta_departamento_barrio-norte_balcon_patio_toilette_luminoso_garage_placard_subte-linea-d_estela-da-onofrio-propiedades
# 2335                                                                                                                    https://www.properati.com.ar/1kc44_venta_departamento_palermo_balcon_baulera_terraza_luminoso_lujoso_placard_subte-linea-d_estela-da-onofrio-propiedades
# ...                                                                                                                                                                                                                                                                          ...
# 16380                                                                                                                                                  https://www.properati.com.ar/1jlos_venta_departamento_saavedra_holmberg_4191_balcon_lavadero_luminoso_addario-propiedades
# 16657                                                                                                                   https://www.properati.com.ar/1kc42_venta_departamento_boedo_balcon_luminoso_placard_subte-linea-h_apto-credito-hipotecario_estela-da-onofrio-propiedades
# 16720                                                                                                              https://www.properati.com.ar/1hjng_venta_departamento_colegiales_maure-3516_balcon_luminoso_garage_aire-acondicionado_subte-linea-b_sebastian-cantero-s-a_6m4
# 16839                                                                                                                               https://www.properati.com.ar/1kc40_venta_departamento_colegiales_balcon_piscina_luminoso_placard_subte-linea-b_estela-da-onofrio-propiedades
# 16920                                                        https://www.properati.com.ar/1irkl_venta_departamento_belgrano_20-de-setiembre_11_balcon_baulera_suite_lavadero_piscina_toilette_vestidor_vista_lujoso_dependencias_electrogeno_garage_fera-cancellieri-propiedades
# 17010                                                                                              https://www.properati.com.ar/1g5ku_venta_departamento_monte-castro_gonzalez-joaquin-v-2160-2-_balcon_vestidor_luminoso_apto-credito-hipotecario_pablo-yaryura-propiedades_bly
# 17610                                                                                                                 https://www.properati.com.ar/1k7bp_venta_departamento_villa-lugano_sayos_6048_balcon_lavadero_luminoso_placard_apto-credito-hipotecario_deseta-propiedades
# 17611                                                                                                                                  https://www.properati.com.ar/1k7bq_venta_ph_villa-lugano_balcon_patio_terraza_luminoso_garage_apto-credito-hipotecario_deseta-propiedades
# 17618                                                                                                                            https://www.properati.com.ar/1kbyy_venta_departamento_villa-lugano_balcon_lavadero_luminoso_placard_apto-credito-hipotecario_deseta-propiedades
# 17620                                                                                                                   https://www.properati.com.ar/1kbz0_venta_departamento_villa-lugano_balcon_lavadero_garage_aire-acondicionado_apto-credito-hipotecario_deseta-propiedades
# 17622                                                                                                                   https://www.properati.com.ar/1kdda_venta_departamento_villa-lugano_balcon_lavadero_toilette_luminoso_vista_garage_placard_francisco-leguizamon-inmuebles
# 17623                                                                                                            https://www.properati.com.ar/1kduf_venta_departamento_villa-lugano_balcon_suite_lavadero_patio_quincho_terraza_garage_aire-acondicionado_maggio-propiedades_3lu
# 17799                                                                                                  https://www.properati.com.ar/1g60i_venta_departamento_san-telmo_garay-juan-de-av-_300_suite_gimnasio_lavadero_piscina_amoblado_luciano-cazenave-inversiones-inmobiliarias
# 17889                                    https://www.properati.com.ar/1i6e8_venta_departamento_san-telmo_paseo-colon-av-1100_balcon_gimnasio_lavadero_parrilla_piscina_quincho_sum_terraza_luminoso_sauna_lujoso_garage_amenities_placard_aire-acondicionado_rcm-propiedades_c67
# 17940                                                 https://www.properati.com.ar/1jmtw_venta_departamento_san-telmo_balcon_suite_gimnasio_lavadero_parrilla_piscina_quincho_sum_terraza_vestidor_luminoso_sauna_lujoso_garage_amenities_aire-acondicionado_rcm-propiedades_c67
# 18000                        https://www.properati.com.ar/1kel7_venta_departamento_san-telmo_balcon_suite_gimnasio_lavadero_parrilla_piscina_quincho_sum_terraza_vestidor_luminoso_sauna_lujoso_garage_amenities_aire-acondicionado_apto-credito-hipotecario_rcm-propiedades_c67
# 18059                                                                                                                           https://www.properati.com.ar/1el6l_venta_departamento_belgrano_forest-avda-1478_balcon_lavadero_luminoso_lujoso_dependencias_new-oro-propiedades
# 18227                                                                                                                                                                       https://www.properati.com.ar/1kf9y_venta_departamento_villa-urquiza_subte-linea-b_ibanez-propiedades
# 18252                                                                                                             https://www.properati.com.ar/1hbuc_venta_departamento_villa-urquiza_av-de-los-incas-4724_balcon_suite_lavadero_patio_vestidor_subte-linea-b_vaizer-propiedades
# 18412                                                                                                                         https://www.properati.com.ar/1jm8f_venta_departamento_parque-chacabuco_la-plata-av-_2300_amoblado_placard_aire-acondicionado_rapisarda-propiedades
# 18413                                                                                                                         https://www.properati.com.ar/1jm8g_venta_departamento_parque-chacabuco_la-plata-av-_2300_amoblado_placard_aire-acondicionado_rapisarda-propiedades
# 18422                                                                                                                         https://www.properati.com.ar/1k7ad_venta_departamento_parque-chacabuco_la-plata-av-_2300_amoblado_placard_aire-acondicionado_rapisarda-propiedades
# 18424                                                                                                                         https://www.properati.com.ar/1k9ai_venta_departamento_parque-chacabuco_la-plata-av-_2300_amoblado_placard_aire-acondicionado_rapisarda-propiedades
# 18495                                                                                                                                                  https://www.properati.com.ar/1hi8a_venta_ph_villa-del-parque_melincue-3282_lavadero_placard_pablo-yaryura-propiedades_bly
# 18621                                                                                                         https://www.properati.com.ar/1jm5d_venta_departamento_villa-del-parque_parrilla_piscina_quincho_toilette_luminoso_garage_amenities_impecable_cimas-propiedades_5c0
# 18657                                                                                                                                      https://www.properati.com.ar/1kapi_venta_departamento_villa-del-parque_helguera_2600_balcon_lavadero_luminoso_genzano-propiedades_apf
# 18665                                                                                                                                                 https://www.properati.com.ar/1kcih_venta_departamento_villa-del-parque_lavadero_luminoso_garage_placard_folger-propiedades
# 18716                                                                                                                             https://www.properati.com.ar/1hjp0_venta_departamento_coghlan_congreso-av-_3500_baulera_luminoso_garage_amenities_estrenar_lacroze-propiedades
# 18717                                                                                                                   https://www.properati.com.ar/1hpij_venta_departamento_coghlan_freire-ramon-2538_suite_parrilla_sum_vestidor_luminoso_garage_estrenar_lacroze-propiedades
# 18729                                                                                             https://www.properati.com.ar/1ihxl_venta_departamento_belgrano_congreso-avda-3125_balcon_lavadero_toilette_luminoso_garage_placard_subte-linea-d_estela-da-onofrio-propiedades
#
#                  barrio  comuna
# 137             PALERMO    14.0
# 140             PALERMO    14.0
# 176             PALERMO    14.0
# 177             PALERMO    14.0
# 180             PALERMO    14.0
# 181             PALERMO    14.0
# 433             PALERMO    14.0
# 511             PALERMO    14.0
# 731             PALERMO    14.0
# 732             PALERMO    14.0
# 733             PALERMO    14.0
# 915             PALERMO    14.0
# 987             PALERMO    14.0
# 1332            PALERMO    14.0
# 1394            PALERMO    14.0
# 1396            PALERMO    14.0
# 1397            PALERMO    14.0
# 1483            PALERMO    14.0
# 1484            PALERMO    14.0
# 1769            PALERMO    14.0
# 1780            PALERMO    14.0
# 1781            PALERMO    14.0
# 1782            PALERMO    14.0
# 2138            PALERMO    14.0
# 2293            PALERMO    14.0
# 2297            PALERMO    14.0
# 2298            PALERMO    14.0
# 2322            PALERMO    14.0
# 2334            PALERMO    14.0
# 2335            PALERMO    14.0
# ...                 ...     ...
# 16380          SAAVEDRA    12.0
# 16657             BOEDO     5.0
# 16720         CHACARITA    15.0
# 16839         CHACARITA    15.0
# 16920              BOCA     4.0
# 17010      MONTE CASTRO    10.0
# 17610      VILLA LUGANO     8.0
# 17611      VILLA LUGANO     8.0
# 17618      VILLA LUGANO     8.0
# 17620      VILLA LUGANO     8.0
# 17622      VILLA LUGANO     8.0
# 17623      VILLA LUGANO     8.0
# 17799         SAN TELMO     1.0
# 17889         SAN TELMO     1.0
# 17940         SAN TELMO     1.0
# 18000         SAN TELMO     1.0
# 18059     VILLA ORTUZAR    15.0
# 18227     VILLA ORTUZAR    15.0
# 18252       PARQUE CHAS    15.0
# 18412     NUEVA POMPEYA     4.0
# 18413     NUEVA POMPEYA     4.0
# 18422     NUEVA POMPEYA     4.0
# 18424     NUEVA POMPEYA     4.0
# 18495  VILLA DEL PARQUE    11.0
# 18621  VILLA DEL PARQUE    11.0
# 18657  VILLA DEL PARQUE    11.0
# 18665  VILLA DEL PARQUE    11.0
# 18716           COGHLAN    12.0
# 18717           COGHLAN    12.0
# 18729           COGHLAN    12.0
#
# [260 rows x 17 columns]

# %% [markdown]
# **7)** A continuación **mostrá** cuantas instancias son las que descartaste a partir de quitar las que tenían valores nulos.

# %%
# Mostrá en esta celda la cantidad de instancias descartadas
df_filtered.isna().sum()
# Out:
# created_on                     0
# operation                      0
# property_type                  0
# place_with_parent_names        0
# lat-lon                        0
# lat                            0
# lon                            0
# price_aprox_usd             1534
# surface_total_in_m2         2393
# surface_covered_in_m2       2103
# price_usd_per_m2            2942
# floor                      16223
# rooms                       5462
# expenses                   15164
# properati_url                  0
# barrio                         0
# comuna                         0
# dtype: int64

# %% [markdown]
# Posiblemente existan otros atributos con valores faltantes en el dataset, pero que no son de tanta importancia.
#
# **8) Mostrá** qué otros atributos tienen valores faltantes en el `dataframe`.

# %%
# Mostrá en esta celda los otros atributos con valores faltant
df_filtered['surface_total_in_m2'].fillna(0)
# Out:
# 2        122.0
# 5         30.0
# 6         26.0
# 8         48.0
# 9         20.0
# 11        70.0
# 12       193.0
# 13        84.0
# 14       185.0
# 15        76.0
# 18       130.0
# 20        70.0
# 21       130.0
# 22       532.0
# 24        67.0
# 25        72.0
# 29        67.0
# 31        40.0
# 35        64.0
# 37        47.0
# 38        38.0
# 39        52.0
# 40       239.0
# 42       200.0
# 43       168.0
# 44        27.0
# 52        44.0
# 53       230.0
# 55       119.0
# 56        58.0
#          ...
# 18924    195.0
# 18925     86.0
# 18926     37.0
# 18927     38.0
# 18928     95.0
# 18929     44.0
# 18931     92.0
# 18932     84.0
# 18933     69.0
# 18934     58.0
# 18935     66.0
# 18936     25.0
# 18939     98.0
# 18941     90.0
# 18942    102.0
# 18943     65.0
# 18944     73.0
# 18946    200.0
# 18948     37.0
# 18949     62.0
# 18952    102.0
# 18953     98.0
# 18954     50.0
# 18955     55.0
# 18956     55.0
# 18959    180.0
# 18960     50.0
# 18961    260.0
# 18962     60.0
# 18963     55.0
# Name: surface_total_in_m2, Length: 12833, dtype: float64

# %% [markdown]
# #### Desafío: planteá alguna estrategia posible para reemplazar los valores faltantes en el atributo `surface_total_in_m2`.

# %% [markdown]
# ## Datos erróneos

# %% [markdown]
# El siguiente paso es analizar errores que puede llegar a haber en el dataset.
#
# Por ejemplo, la **superficie total no puede ser menor que la cubierta**. Si esto sucede, podemos optar por eliminar esas filas o intentar corregir el problema. Veamos en primer lugar si esto sucede.
#
# **9) Mostrá** cuantas instancias existen que tengan el problema de este dato erróneo y guardalas en una variable llamada `wrong_surface_rows`

# %%
# Mostrá en esta celda cuántas instancias tienen errores en la superficie
wrong_surface_rows = df_filtered[df_filtered['surface_total_in_m2'] < df_filtered['surface_covered_in_m2']]
wrong_surface_rows.head()
# Out:
#       created_on operation property_type  \
# 106   2017-09-07      sell         house
# 153   2017-09-12      sell     apartment
# 657   2017-10-17      sell     apartment
# 935   2017-11-06      sell     apartment
# 1174  2017-11-22      sell         house
#
#                                place_with_parent_names  \
# 106               |Argentina|Capital Federal|Belgrano|
# 153                |Argentina|Capital Federal|Palermo|
# 657   |Argentina|Capital Federal|Palermo|Palermo Soho|
# 935                |Argentina|Capital Federal|Palermo|
# 1174               |Argentina|Capital Federal|Palermo|
#
#                             lat-lon        lat        lon  price_aprox_usd  \
# 106           -34.566867,-58.444197 -34.566867 -58.444197        1650000.0
# 153         -34.5830704,-58.4241896 -34.583070 -58.424190         140000.0
# 657   -34.5827102814,-58.4268853069 -34.582710 -58.426885         307300.0
# 935         -34.5869532,-58.4189032 -34.586953 -58.418903         275000.0
# 1174          -34.583652,-58.444111 -34.583652 -58.444111         930000.0
#
#       surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  floor  \
# 106                 455.0                  456.0       3626.373626    NaN
# 153                  39.0                   44.0       3589.743590    NaN
# 657                  59.0                   63.0       5208.474576    NaN
# 935                  13.0                   79.0      21153.846154    1.0
# 1174                205.0                  343.0       4536.585366    NaN
#
#       rooms  expenses  \
# 106     5.0       NaN
# 153     1.0       NaN
# 657     NaN       NaN
# 935     4.0       NaN
# 1174    5.0       NaN
#
#                                                                                                                                                                                                                             properati_url  \
# 106                          https://www.properati.com.ar/1ehbq_venta_casa_belgrano_suite_gimnasio_hidromasaje_jardin_lavadero_parrilla_patio_quincho_terraza_toilette_vestidor_luminoso_lujoso_garage_impecable_subte-linea-d_re-max-win
# 153                                                                                                                       https://www.properati.com.ar/1en9l_venta_departamento_palermo_luminoso_estrenar_subte-linea-d_mavia-propiedades
# 657   https://www.properati.com.ar/1gyrq_venta_departamento_palermo-soho_baulera_gimnasio_parrilla_piscina_sum_terraza_luminoso_vista_sauna_garage_amoblado_amenities_aire-acondicionado_estrenar_losa-radiante_subte-linea-d_devoto-citi
# 935                                                                            https://www.properati.com.ar/1htrv_venta_departamento_palermo_scalabrini-ortiz-av-r-_2300_baulera_patio_toilette_dependencias_garage_bengochea-propiedades
# 1174                                                                                                                  https://www.properati.com.ar/1ibt5_venta_casa_palermo_balcon_lavadero_parrilla_patio_terraza_garage_re-max-total-iv
#
#        barrio  comuna
# 106   PALERMO    14.0
# 153   PALERMO    14.0
# 657   PALERMO    14.0
# 935   PALERMO    14.0
# 1174  PALERMO    14.0

# %% [markdown]
# Proponemos no borrar estas instancias erróneas, sino intercambiar los valores de **superficie total** con **superficie cubierta** en caso de que se cumpla la condición mencionada.

# %%
df_filtered.at[wrong_surface_rows.index, 'surface_total_in_m2'] = wrong_surface_rows.surface_covered_in_m2
df_filtered.at[wrong_surface_rows.index, 'surface_covered_in_m2'] = wrong_surface_rows.surface_total_in_m2
# ya no existe filas con valores incorrectos
df_filtered[df_filtered['surface_total_in_m2'] < df_filtered['surface_covered_in_m2']]
# Out:
# Empty DataFrame
# Columns: [created_on, operation, property_type, place_with_parent_names, lat-lon, lat, lon, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, floor, rooms, expenses, properati_url, barrio, comuna]
# Index: []

# %% [markdown]
# Por otro lado, sucede que las inmobiliarias cuando no cuentan con las coordenadas reales de las propiedades utilizan valores que no son correctos. Por ejemplo, el punto centro de cada barrio o puntos de interés como el Obelisco. Esto puede afectar el análisis relacionado con la ubicación de cada propiedad.
#
# Veamos en primer lugar si hay coordenadas que se repiten.

# %%
conteo_puntos = df_filtered.groupby(['lat', 'lon']).size()
conteo_puntos[conteo_puntos > 1].sort_values(ascending=False).head(10)
# Out:
# lat         lon
# -34.589546  -58.397364    160
# -34.571150  -58.423297    128
# -34.562084  -58.456686     91
# -34.620928  -58.445874     49
# -34.609821  -58.392606     47
# -34.622973  -58.439913     41
# -34.608608  -58.448515     40
# -34.603771  -58.381587     37
# -34.617719  -58.362056     36
# -34.621184  -58.373116     33
# dtype: int64

# %% [markdown]
# Por ejemplo, para el caso del tercer punto, se puede verificar que corresponde a la esquina de Av. Cabildo y Juramento.
# Nos quedamos entonces con las propiedades con coordenadas que se repitan hasta 5 veces.

# %%
conteo_puntos.name = 'conteo'

df_filtered = df_filtered.join(conteo_puntos, on=['lat', 'lon'])

df_filtered = df_filtered[df_filtered.conteo <= 5]

# %% [markdown]
# Eliminamos el atributo `conteo` dado que ya no nos sirve.

# %%
df_filtered.drop('conteo', inplace=True, axis=1)

# %% [markdown]
# ## Estudiando los barrios

# %% [markdown]
# ### Barrios con más edificios y barrios con más casas
# Al saber qué barrios son los que tienen más cantidad de edificios en venta y cuáles son los que tienen más casas podemos darnos una idea de qué tipo de barrio es. Si es más residencial, con más población, poder adquisitivo, etc.
# Para eso vamos a empezar calculando los porcentajes de cada tipo de propiedad según el barrio.

# %%
total_propiedades = df_filtered.groupby('barrio')['property_type'].count().values
total_propiedades
# Out:
# array([  57,  717,  924,  211, 1018,  136,  173,  919,  174,  117,  263,
#         256,  726,  197,  342,  217,  384,  160,  103,  375, 2143,  128,
#         203,   89,  147,   88,  277, 1394,  565,  258,  205,  502,  197,
#         147,   73,  582,  217,  307,  138,  130,  206,  148,  143,   52,
#          26,   98,   16,  484])

# %%
porcentaje_casas_ph = df_filtered[df_filtered.property_type.isin(['PH', 'house'])].groupby('barrio').count().property_type/total_propiedades
porcentaje_edificios = df_filtered[df_filtered.property_type == 'apartment'].groupby('barrio').count().property_type/total_propiedades

# %%
print("Barrios con mayor porcentaje de edificios: \n", porcentaje_edificios.sort_values()[::-1][:5])
print("Barrios con mayor porcentaje de casas y phs: \n ", porcentaje_casas_ph.sort_values()[::-1][:5])
# Out:
# Barrios con mayor porcentaje de edificios:
#  barrio
# PUERTO MADERO    0.971119
# RECOLETA         0.945481
# RETIRO           0.883186
# PALERMO          0.875408
# BELGRANO         0.874263
# Name: property_type, dtype: float64
# Barrios con mayor porcentaje de casas y phs:
#   barrio
# VILLA RIACHUELO      0.730769
# VERSALLES            0.643836
# MATADEROS            0.589862
# PARQUE AVELLANEDA    0.554688
# NUEVA POMPEYA        0.553398
# Name: property_type, dtype: float64

# %% [markdown]
# Para darnos una idea de las diferencias entre los porcentajes de edificios y casas en estos barrios, vamos a graficarlos
# en forma de torta.

# %%
barrios_casas = porcentaje_casas_ph.sort_values()[::-1][:5].index
barrios_edificios = porcentaje_edificios.sort_values()[::-1][:5].index
fig, axs = plt.subplots(1,2,figsize=(14,7))
df_filtered[df_filtered.barrio.isin(barrios_edificios)].property_type.value_counts().plot(x=None,y=None, kind='pie', startangle=30, ax=axs[0],autopct='%1.2f%%')
df_filtered[df_filtered.barrio.isin(barrios_casas)].property_type.value_counts().plot(x=None,y=None, kind='pie', ax=axs[1],autopct='%1.2f%%')

# %% [markdown]
# ### Barrios más caros y más baratos

# %% [markdown]
# Veamos primero la distribución del precio por metro cuadrado para todo el dataset. De esta manera, vamos a remover valores que consideremos extremos.
#
# En el siguiente proyecto vamos a volver sobre este tema con más profundidad.
#
# **10)** Tomando el atributo `price_usd_per_m2` **calculá** su **mínimo**, **máximo**, **promedio (mean)**, **mediana (median)** y **desvío estándar (std)**

# %%
# Mostrá en esta celda los cálculos
df_filtered.dropna()
min = df_filtered['price_usd_per_m2'].min()
max = df_filtered['price_usd_per_m2'].max()
mean = df_filtered['price_usd_per_m2'].mean()
median = df_filtered['price_usd_per_m2'].median()
std = df_filtered['price_usd_per_m2'].std()

print("Valor Minimo", min)
print("Valor Maximo", max)
print("Promedio", mean)
print("Mediana", median)
print("Desvio estandar", std)
# Out:
# Valor Minimo 1481.4814814814815
# Valor Maximo 4067.796610169493
# Promedio 2584.7275272312486
# Mediana 2545.436363636364
# Desvio estandar 615.3190268519706

# %% [markdown]
# También podemos calcular otros estadísticos como los cuartiles.
#
# **11) Mostrá** el **primer y tercer cuartil** y luego también el **rango intercuartilíco**

# %%
# Mostrá los cuartiles en esta celda
df_filtered['price_usd_per_m2'].quantile(.1)
df_filtered['price_usd_per_m2'].quantile(.3)
df_filtered['price_usd_per_m2'].quantile()
# Out:
# 2500.0

# %% [markdown]
# **Rango intercuartilico IQR**

# %%
rango = df_filtered['price_usd_per_m2'].max() - df_filtered['price_usd_per_m2'].min()
iqr = df_filtered['price_usd_per_m2'].quantile(0.75) - df_filtered['price_usd_per_m2'].quantile(0.25)
print("Rango Intercuartilíco", iqr)
# Out:
# Rango Intercuartilíco 1207.792207792208

# %% [markdown]
# ### Quitando valores extremos
# Eliminemos aquellas observaciones cuyo precio por metro cuadrado este fuera de los percentiles 10 y 90. De este modo intentaremos remover valores extremos de una manera sencilla para tener un análisis más robusto.

# %%
df = pd.read_csv('dataset/datos_properati.csv')
df_filtered = pd.DataFrame(df)
p10 = np.percentile(df_filtered.price_usd_per_m2.dropna(), 10)
p90 = np.percentile(df_filtered.price_usd_per_m2.dropna(), 90)
print("Valor Minimo", p10)
print("Valor Maximo", p90)
df_filtered = df_filtered[(df_filtered.price_usd_per_m2 >= p10) & (df_filtered.price_usd_per_m2 <= p90)]
df_filtered
# Out:
# Valor Minimo 1481.4814814814815
# Valor Maximo 4068.1289464938523
#        created_on operation property_type  \
# 2      2017-08-02      sell         store
# 5      2017-08-09      sell         store
# 6      2017-08-11      sell         store
# 8      2017-08-12      sell         store
# 9      2017-08-15      sell         store
# 11     2017-08-16      sell         store
# 12     2017-08-16      sell         store
# 13     2017-08-18      sell         store
# 14     2017-08-26      sell         store
# 15     2017-08-26      sell         store
# 18     2017-08-29      sell     apartment
# 20     2017-08-29      sell     apartment
# 21     2017-08-30      sell         store
# 22     2017-08-30      sell         house
# 24     2017-08-30      sell     apartment
# 25     2017-08-30      sell            PH
# 29     2017-08-30      sell     apartment
# 31     2017-08-30      sell     apartment
# 35     2017-08-31      sell     apartment
# 37     2017-08-31      sell     apartment
# 38     2017-08-31      sell     apartment
# 39     2017-08-31      sell     apartment
# 40     2017-09-01      sell     apartment
# 42     2017-09-01      sell     apartment
# 43     2017-09-01      sell     apartment
# 44     2017-09-01      sell     apartment
# 52     2017-09-02      sell     apartment
# 53     2017-09-02      sell     apartment
# 55     2017-09-03      sell     apartment
# 56     2017-09-03      sell            PH
# ...           ...       ...           ...
# 18924  2018-01-19      sell         house
# 18925  2018-01-19      sell     apartment
# 18926  2018-01-19      sell     apartment
# 18927  2018-01-19      sell     apartment
# 18928  2018-01-19      sell            PH
# 18929  2018-01-19      sell     apartment
# 18931  2018-01-20      sell     apartment
# 18932  2018-01-20      sell     apartment
# 18933  2018-01-20      sell     apartment
# 18934  2018-01-20      sell     apartment
# 18935  2018-01-20      sell     apartment
# 18936  2018-01-20      sell     apartment
# 18939  2018-01-20      sell            PH
# 18941  2018-01-20      sell     apartment
# 18942  2018-01-20      sell     apartment
# 18943  2018-01-20      sell     apartment
# 18944  2018-01-20      sell     apartment
# 18946  2018-01-20      sell         house
# 18948  2018-01-22      sell     apartment
# 18949  2018-01-26      sell     apartment
# 18952  2018-01-26      sell         house
# 18953  2018-01-26      sell            PH
# 18954  2018-01-26      sell            PH
# 18955  2018-01-26      sell     apartment
# 18956  2018-01-26      sell     apartment
# 18959  2018-01-29      sell            PH
# 18960  2018-01-31      sell     apartment
# 18961  2018-01-31      sell         house
# 18962  2018-01-31      sell            PH
# 18963  2017-09-22      sell     apartment
#
#                                      place_with_parent_names  \
# 2           |Argentina|Capital Federal|Palermo|Palermo Soho|
# 5                        |Argentina|Capital Federal|Palermo|
# 6                       |Argentina|Capital Federal|Belgrano|
# 8                        |Argentina|Capital Federal|Palermo|
# 9                        |Argentina|Capital Federal|Palermo|
# 11                  |Argentina|Capital Federal|Barrio Norte|
# 12     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 13                       |Argentina|Capital Federal|Palermo|
# 14                      |Argentina|Capital Federal|Belgrano|
# 15                       |Argentina|Capital Federal|Palermo|
# 18                       |Argentina|Capital Federal|Palermo|
# 20                       |Argentina|Capital Federal|Palermo|
# 21                       |Argentina|Capital Federal|Palermo|
# 22     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 24     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 25          |Argentina|Capital Federal|Palermo|Palermo Soho|
# 29                       |Argentina|Capital Federal|Palermo|
# 31                       |Argentina|Capital Federal|Palermo|
# 35     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 37                       |Argentina|Capital Federal|Palermo|
# 38                       |Argentina|Capital Federal|Palermo|
# 39                       |Argentina|Capital Federal|Palermo|
# 40                  |Argentina|Capital Federal|Barrio Norte|
# 42                         |Argentina|Capital Federal|Nuñez|
# 43                      |Argentina|Capital Federal|Belgrano|
# 44                       |Argentina|Capital Federal|Palermo|
# 52     |Argentina|Capital Federal|Palermo|Palermo Hollywood|
# 53                       |Argentina|Capital Federal|Palermo|
# 55                       |Argentina|Capital Federal|Palermo|
# 56                       |Argentina|Capital Federal|Palermo|
# ...                                                      ...
# 18924           |Argentina|Capital Federal|Villa Pueyrredón|
# 18925           |Argentina|Capital Federal|Villa Pueyrredón|
# 18926           |Argentina|Capital Federal|Villa Pueyrredón|
# 18927           |Argentina|Capital Federal|Villa Pueyrredón|
# 18928           |Argentina|Capital Federal|Villa Pueyrredón|
# 18929           |Argentina|Capital Federal|Villa Pueyrredón|
# 18931           |Argentina|Capital Federal|Villa Pueyrredón|
# 18932           |Argentina|Capital Federal|Villa Pueyrredón|
# 18933           |Argentina|Capital Federal|Villa Pueyrredón|
# 18934           |Argentina|Capital Federal|Villa Pueyrredón|
# 18935           |Argentina|Capital Federal|Villa Pueyrredón|
# 18936           |Argentina|Capital Federal|Villa Pueyrredón|
# 18939           |Argentina|Capital Federal|Villa Pueyrredón|
# 18941           |Argentina|Capital Federal|Villa Pueyrredón|
# 18942           |Argentina|Capital Federal|Villa Pueyrredón|
# 18943                   |Argentina|Capital Federal|Belgrano|
# 18944           |Argentina|Capital Federal|Villa Pueyrredón|
# 18946           |Argentina|Capital Federal|Villa Pueyrredón|
# 18948               |Argentina|Capital Federal|Villa Devoto|
# 18949           |Argentina|Capital Federal|Villa Pueyrredón|
# 18952                   |Argentina|Capital Federal|Belgrano|
# 18953           |Argentina|Capital Federal|Villa Pueyrredón|
# 18954           |Argentina|Capital Federal|Villa Pueyrredón|
# 18955              |Argentina|Capital Federal|Villa Urquiza|
# 18956                  |Argentina|Capital Federal|Agronomía|
# 18959           |Argentina|Capital Federal|Villa Pueyrredón|
# 18960           |Argentina|Capital Federal|Villa Pueyrredón|
# 18961           |Argentina|Capital Federal|Villa Pueyrredón|
# 18962           |Argentina|Capital Federal|Villa Pueyrredón|
# 18963               |Argentina|Capital Federal|Villa Lugano|
#
#                              lat-lon        lat        lon  price_aprox_usd  \
# 2             -34.589723,-58.4325664 -34.589723 -58.432566        343000.00
# 5          -34.57582474,-58.43432236 -34.575825 -58.434322        120000.00
# 6            -34.5739059,-58.4391946 -34.573906 -58.439195        100000.00
# 8            -34.5956086,-58.4247641 -34.595609 -58.424764        110000.00
# 9            -34.5580305,-58.4170088 -34.558031 -58.417009         50000.00
# 11            -34.584198,-58.4152675 -34.584198 -58.415268        170000.00
# 12     -34.5841882044,-58.4431635937 -34.584188 -58.443164        360000.00
# 13             -34.577645,-58.433104 -34.577645 -58.433104        219000.00
# 14           -34.5699614,-58.4323397 -34.569961 -58.432340        685000.00
# 15            -34.573524,-58.4405828 -34.573524 -58.440583        248675.00
# 18      -34.588912403,-58.4134942185 -34.588912 -58.413494        340000.00
# 20           -34.5950139,-58.4273915 -34.595014 -58.427392        180000.00
# 21           -34.5817764,-58.4224975 -34.581776 -58.422497        400000.00
# 22           -34.5793535,-58.4364489 -34.579354 -58.436449       1200000.00
# 24           -34.5809281,-58.4404321 -34.580928 -58.440432        270000.00
# 25            -34.5897765,-58.428558 -34.589776 -58.428558        219000.00
# 29            -34.594251,-58.4166447 -34.594251 -58.416645        250000.00
# 31           -34.5711496,-58.4232966 -34.571150 -58.423297        119124.77
# 35           -34.5825677,-58.4329982 -34.582568 -58.432998        198000.00
# 37             -34.570648,-58.433619 -34.570648 -58.433619        159800.00
# 38             -34.570648,-58.433619 -34.570648 -58.433619        144400.00
# 39             -34.570648,-58.433619 -34.570648 -58.433619        169000.00
# 40         -34.57548904,-58.41962433 -34.575489 -58.419624        510000.00
# 42     -34.5672629609,-58.4318401926 -34.567263 -58.431840        640000.00
# 43           -34.5670278,-58.4353992 -34.567028 -58.435399        590000.00
# 44      -34.5914774208,-58.418185265 -34.591477 -58.418185         90000.00
# 52           -34.5865906,-58.4372126 -34.586591 -58.437213        150000.00
# 53           -34.5925314,-58.4178626 -34.592531 -58.417863        620000.00
# 55             -34.5874885,-58.41578 -34.587488 -58.415780        345000.00
# 56           -34.5933965,-58.4284618 -34.593397 -58.428462        154000.00
# ...                              ...        ...        ...              ...
# 18924        -34.5881853,-58.5067874 -34.588185 -58.506787        430000.00
# 18925        -34.5910338,-58.5060277 -34.591034 -58.506028        160000.00
# 18926        -34.5878677,-58.5048592 -34.587868 -58.504859         93000.00
# 18927        -34.5878677,-58.5048592 -34.587868 -58.504859         91000.00
# 18928        -34.5807783,-58.5058262 -34.580778 -58.505826        215000.00
# 18929        -34.5807783,-58.5058262 -34.580778 -58.505826        120000.00
# 18931          -34.577607,-58.507558 -34.577607 -58.507558        167220.00
# 18932          -34.577607,-58.507558 -34.577607 -58.507558        148230.00
# 18933          -34.577607,-58.507558 -34.577607 -58.507558        131280.00
# 18934          -34.587787,-58.493925 -34.587787 -58.493925        135000.00
# 18935          -34.587945,-58.505325 -34.587945 -58.505325        185000.00
# 18936        -34.5798877,-58.5001446 -34.579888 -58.500145         82000.00
# 18939        -34.5841235,-58.5110034 -34.584123 -58.511003        225000.00
# 18941         -34.577302,-58.5084239 -34.577302 -58.508424        150860.00
# 18942         -34.577302,-58.5084239 -34.577302 -58.508424        159600.00
# 18943         -34.588297,-58.5015889 -34.588297 -58.501589        175000.00
# 18944  -34.5857635862,-58.5009641376 -34.585764 -58.500964        198000.00
# 18946  -34.5810962996,-58.5134651313 -34.581096 -58.513465        360000.00
# 18948        -34.5876068,-58.5053405 -34.587607 -58.505341         92500.00
# 18949          -34.574804,-58.511286 -34.574804 -58.511286        115000.00
# 18952         -34.577302,-58.5084239 -34.577302 -58.508424        158840.00
# 18953        -34.5814759,-58.5055408 -34.581476 -58.505541        187000.00
# 18954        -34.5844982,-58.5058017 -34.584498 -58.505802        145000.00
# 18955  -34.5869610349,-58.4991220286 -34.586961 -58.499122        145000.00
# 18956  -34.5857925673,-58.4991678032 -34.585793 -58.499168        145000.00
# 18959            -34.5848,-58.490567 -34.584800 -58.490567        289900.00
# 18960          -34.582448,-58.507942 -34.582448 -58.507942        115000.00
# 18961        -34.5829089,-58.4928668 -34.582909 -58.492867        448000.00
# 18962        -34.5861739,-58.5063677 -34.586174 -58.506368        148500.00
# 18963          -34.662435,-58.466795 -34.662435 -58.466795         88000.00
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  floor  \
# 2                    122.0                  108.0       2811.475410    NaN
# 5                     30.0                   30.0       4000.000000    1.0
# 6                     26.0                    NaN       3846.153846    NaN
# 8                     48.0                   48.0       2291.666667    NaN
# 9                     20.0                   20.0       2500.000000    NaN
# 11                    70.0                   70.0       2428.571429    NaN
# 12                   193.0                  176.0       1865.284974    NaN
# 13                    84.0                   84.0       2607.142857    NaN
# 14                   185.0                  185.0       3702.702703    NaN
# 15                    76.0                   76.0       3272.039474    NaN
# 18                   130.0                  120.0       2615.384615    NaN
# 20                    70.0                   70.0       2571.428571    NaN
# 21                   130.0                  130.0       3076.923077    NaN
# 22                   532.0                  334.0       2255.639098    NaN
# 24                    67.0                   64.0       4029.850746    NaN
# 25                    72.0                    NaN       3041.666667    NaN
# 29                    67.0                   60.0       3731.343284    NaN
# 31                    40.0                   36.0       2978.119250    NaN
# 35                    64.0                   48.0       3093.750000    NaN
# 37                    47.0                   47.0       3400.000000    2.0
# 38                    38.0                   38.0       3800.000000    2.0
# 39                    52.0                   47.0       3250.000000    2.0
# 40                   239.0                  127.0       2133.891213    NaN
# 42                   200.0                  185.0       3200.000000    NaN
# 43                   168.0                  157.0       3511.904762    NaN
# 44                    27.0                   27.0       3333.333333    NaN
# 52                    44.0                   44.0       3409.090909    NaN
# 53                   230.0                  198.0       2695.652174    NaN
# 55                   119.0                  116.0       2899.159664    NaN
# 56                    58.0                   58.0       2655.172414    NaN
# ...                    ...                    ...               ...    ...
# 18924                195.0                  195.0       2205.128205    NaN
# 18925                 86.0                   77.0       1860.465116    NaN
# 18926                 37.0                   37.0       2513.513514    NaN
# 18927                 38.0                   38.0       2394.736842    NaN
# 18928                 95.0                   77.0       2263.157895    NaN
# 18929                 44.0                   40.0       2727.272727    NaN
# 18931                 92.0                   48.0       1817.608696    NaN
# 18932                 84.0                   36.0       1764.642857    NaN
# 18933                 69.0                   47.0       1902.608696    NaN
# 18934                 58.0                   54.0       2327.586207    5.0
# 18935                 66.0                   58.0       2803.030303    1.0
# 18936                 25.0                   23.0       3280.000000    NaN
# 18939                 98.0                   57.0       2295.918367    NaN
# 18941                 90.0                   72.0       1676.222222    NaN
# 18942                102.0                   72.0       1564.705882    NaN
# 18943                 65.0                   50.0       2692.307692    NaN
# 18944                 73.0                   65.0       2712.328767    NaN
# 18946                200.0                  140.0       1800.000000    NaN
# 18948                 37.0                   37.0       2500.000000    NaN
# 18949                 62.0                   56.0       1854.838710    3.0
# 18952                102.0                   72.0       1557.254902    NaN
# 18953                 98.0                   90.0       1908.163265    NaN
# 18954                 50.0                   40.0       2900.000000    NaN
# 18955                 55.0                   52.0       2636.363636    NaN
# 18956                 55.0                   52.0       2636.363636    NaN
# 18959                180.0                  180.0       1610.555556    NaN
# 18960                 50.0                   50.0       2300.000000    6.0
# 18961                260.0                    NaN       1723.076923    NaN
# 18962                 60.0                    NaN       2475.000000    NaN
# 18963                 55.0                   55.0       1600.000000    NaN
#
#        rooms  expenses  \
# 2        2.0       NaN
# 5        NaN       NaN
# 6        NaN       NaN
# 8        NaN       NaN
# 9        NaN       NaN
# 11       NaN    2800.0
# 12       NaN       NaN
# 13       NaN       NaN
# 14       NaN       NaN
# 15       NaN       NaN
# 18       4.0    8000.0
# 20       NaN    3000.0
# 21       NaN       NaN
# 22       6.0       NaN
# 24       3.0    3900.0
# 25       3.0       NaN
# 29       2.0       NaN
# 31       1.0       NaN
# 35       2.0       NaN
# 37       1.0       NaN
# 38       1.0       NaN
# 39       1.0       NaN
# 40       2.0       NaN
# 42       4.0   18000.0
# 43       4.0   20000.0
# 44       1.0    1140.0
# 52       1.0       NaN
# 53       6.0       NaN
# 55       NaN       NaN
# 56       2.0       NaN
# ...      ...       ...
# 18924    NaN       NaN
# 18925    3.0       NaN
# 18926    2.0       NaN
# 18927    2.0       NaN
# 18928    3.0       NaN
# 18929    2.0       NaN
# 18931    2.0       NaN
# 18932    2.0       NaN
# 18933    2.0       NaN
# 18934    3.0       NaN
# 18935    3.0       NaN
# 18936    1.0       NaN
# 18939    3.0     500.0
# 18941    2.0       NaN
# 18942    2.0       NaN
# 18943    3.0       NaN
# 18944    3.0    2950.0
# 18946    NaN       NaN
# 18948    2.0    1990.0
# 18949    3.0       NaN
# 18952    NaN       NaN
# 18953    3.0       NaN
# 18954    2.0       NaN
# 18955    3.0       NaN
# 18956    3.0       NaN
# 18959    4.0       NaN
# 18960    2.0       NaN
# 18961    4.0       NaN
# 18962    2.0       NaN
# 18963    3.0       NaN
#
#                                                                                                                                                                                                                    properati_url  \
# 2                                                                                 https://www.properati.com.ar/1cm8w_venta_local_palermo-soho_cabrera-jose-a-_5000_jardin_lavadero_patio_piscina_toilette_garage_ojo-propiedades
# 5                                                                                                         https://www.properati.com.ar/1cw7a_venta_local_palermo_av-santa-fe_5300_garage_subte-linea-d_solucion-inmobiliaria_gx3
# 6                                                                                   https://www.properati.com.ar/1d36i_venta_local_belgrano_dumont-santos_2400_luminoso_impecable_subte-linea-d_urbana-consultores-inmobiliarios
# 8                                                                                                                                                    https://www.properati.com.ar/1d5sl_venta_local_palermo_zappone-inmobiliaria
# 9                                                                                                                       https://www.properati.com.ar/1d86m_venta_local_palermo_santa-fe-av-_4400_subte-linea-d_gaed-inmobiliaria
# 11                                                                                                     https://www.properati.com.ar/1dcnv_venta_local_barrio-norte_arenales_3800_subte-linea-d_zuker-servicios-inmobiliarios_gsp
# 12                                                                                                           https://www.properati.com.ar/1dd77_venta_local_palermo-hollywood_balcon_lavadero_terraza_metro-estudio-inmobiliario
# 13                                                                                                                                     https://www.properati.com.ar/1di5h_venta_local_palermo_subte-linea-d_re-max-ra-iacute-ces
# 14                                                                                                                https://www.properati.com.ar/1dv8b_venta_local_belgrano_subte-linea-d_maxi-totah-operaciones-inmobiliarias_e2l
# 15                                                                                                           https://www.properati.com.ar/1dw79_venta_local_palermo_matienzo-benjamin-2489_subte-linea-d_aguero-vera-propiedades
# 18       https://www.properati.com.ar/1dzv6_venta_departamento_palermo_guemes_3600_balcon_suite_jardin_lavadero_luminoso_lujoso_dependencias_placard_doble-circulacion_subte-linea-d_luisio-propiedades-suc-virrey-del-pino-2378
# 20                                                                                            https://www.properati.com.ar/1e0mq_venta_departamento_palermo_julian-alvarez-al-1200_lavadero_amoblado_sanchez-carrizo-real-estate
# 21                                                                                                                                   https://www.properati.com.ar/1e1lu_venta_local_palermo_thames_2400_subte-linea-d_de-locales
# 22                                                                                            https://www.properati.com.ar/1e1ve_venta_casa_palermo-hollywood_jardin_lavadero_piscina_luminoso_vista_garage_nexo-propiedades_h0z
# 24                                                                           https://www.properati.com.ar/1e1x0_venta_departamento_palermo-hollywood_arevalo_1700_balcon_toilette_luminoso_apto-credito-hipotecario_yankel-group
# 25                                                                                                                         https://www.properati.com.ar/1e1xj_venta_ph_palermo-soho_honduras_4800_patio_luminoso_ojo-propiedades
# 29                                                               https://www.properati.com.ar/1e2mz_venta_departamento_palermo_balcon_lavadero_parrilla_piscina_aire-acondicionado_apto-credito-hipotecario_ageo-propiedades_dwr
# 31                                                                                                          https://www.properati.com.ar/1e2of_venta_departamento_palermo_jardin_lavadero_parrilla_amenities_aprop-bienes-raices
# 35                                                                           https://www.properati.com.ar/1e4f0_venta_departamento_palermo-hollywood_balcon_terraza_luminoso_amenities_aire-acondicionado_arkis-inmobiliaria_eoh
# 37                                                                                                          https://www.properati.com.ar/1e4tm_venta_departamento_palermo_balcon_luminoso_estrenar_subte-linea-d_re-max-d-bosion
# 38                                                                                                          https://www.properati.com.ar/1e4tp_venta_departamento_palermo_balcon_luminoso_estrenar_subte-linea-d_re-max-d-bosion
# 39                                                                                                          https://www.properati.com.ar/1e4tr_venta_departamento_palermo_balcon_luminoso_estrenar_subte-linea-d_re-max-d-bosion
# 40                                                                 https://www.properati.com.ar/1e66w_venta_departamento_barrio-norte_de-maria_4300_baulera_patio_subte-linea-d_apto-credito-hipotecario_grupo-zeta-inmobiliaria
# 42                  https://www.properati.com.ar/1e6hy_venta_departamento_nunez_san-benito-de-palermo_1500_balcon_baulera_suite_lavadero_toilette_vestidor_lujoso_dependencias_garage_aire-acondicionado_filippo-propiedades_9im
# 43     https://www.properati.com.ar/1e6s5_venta_departamento_belgrano_soldado-de-la-independencia_900_balcon_baulera_suite_lavadero_toilette_vestidor_luminoso_lujoso_garage_impecable_aire-acondicionado_shenk-inmobiliaria_gkj
# 44                                                                                                                         https://www.properati.com.ar/1e6su_venta_departamento_palermo_luminoso_placard_shenk-inmobiliaria_gkj
# 52                                                                                              https://www.properati.com.ar/1e9j1_venta_departamento_palermo-hollywood_baulera_gimnasio_hidromasaje_lavadero_luminoso_l-e-group
# 53                                                                  https://www.properati.com.ar/1e9ob_venta_departamento_palermo_balcon_suite_lavadero_toilette_luminoso_lujoso_garage_subte-linea-d_fabian-achaval-propiedades
# 55                                             https://www.properati.com.ar/1ea4p_venta_departamento_palermo_alvarez-julian_2481_balcon_baulera_suite_lavadero_toilette_luminoso_impecable_subte-linea-d_a-sourigues-propiedades
# 56                                                                                                        https://www.properati.com.ar/1ea8c_venta_ph_palermo_parrilla_patio_apto-credito-hipotecario_migliorisi-propiedades_dkd
# ...                                                                                                                                                                                                                          ...
# 18924                                                                       https://www.properati.com.ar/1jr4v_venta_casa_villa-pueyrredon_balcon_suite_parrilla_piscina_quincho_toilette_vestidor_garage_sotelo-propiedades_f7b
# 18925                                                                                  https://www.properati.com.ar/1jri2_venta_departamento_villa-pueyrredon_balcon_lavadero_placard_apto-credito-hipotecario_hakim-propiedades
# 18926                                                                                         https://www.properati.com.ar/1jrra_venta_departamento_villa-pueyrredon_placard_apto-credito-hipotecario_bienvende-amelia-claro_ej0
# 18927                                                                                       https://www.properati.com.ar/1jrrv_venta_departamento_villa-pueyrredon_lavadero_placard_apto-credito-hipotecario_barrena-propiedades
# 18928                                                                                                                         https://www.properati.com.ar/1js05_venta_ph_villa-pueyrredon_lavadero_patio_guimat-propiedades_e7u
# 18929                                                                                          https://www.properati.com.ar/1jtig_venta_departamento_villa-pueyrredon_balcon_luminoso_placard_estrenar_norbaires-propiedades_huj
# 18931                                                                                                          https://www.properati.com.ar/1ju4e_venta_departamento_villa-pueyrredon_baulera_piscina_luminoso_garage_re-max-uno
# 18932                                                                                                          https://www.properati.com.ar/1ju4f_venta_departamento_villa-pueyrredon_baulera_piscina_luminoso_garage_re-max-uno
# 18933                                                                                                          https://www.properati.com.ar/1ju4g_venta_departamento_villa-pueyrredon_baulera_piscina_luminoso_garage_re-max-uno
# 18934                                                                                                                 https://www.properati.com.ar/1ju4m_venta_departamento_villa-pueyrredon_balcon_lavadero_luminoso_re-max-uno
# 18935                                                                                             https://www.properati.com.ar/1jugk_venta_departamento_villa-pueyrredon_balcon_baulera_lavadero_luminoso_placard_re-max-avenida
# 18936                                                                                         https://www.properati.com.ar/1jv94_venta_departamento_villa-pueyrredon_lavadero_luminoso_garage_placard_laurenzano-propiedades_glv
# 18939                                                                                  https://www.properati.com.ar/1jyjw_venta_ph_villa-pueyrredon_balcon_lavadero_parrilla_terraza_luminoso_placard_laurenzano-propiedades_glv
# 18941                                                                              https://www.properati.com.ar/1jyue_venta_departamento_villa-pueyrredon_suite_patio_toilette_garage_aire-acondicionado_century-21-republicador
# 18942                                                                     https://www.properati.com.ar/1jyug_venta_departamento_villa-pueyrredon_balcon_suite_terraza_toilette_garage_aire-acondicionado_century-21-republicador
# 18943                                            https://www.properati.com.ar/1jyvc_venta_departamento_velez-sarsfield_balcon_baulera_suite_parrilla_terraza_aire-acondicionado_apto-credito-hipotecario_century-21-republicador
# 18944                                                                          https://www.properati.com.ar/1jzlj_venta_departamento_villa-pueyrredon_terrada_4700_balcon_toilette_luminoso_impecable_laurenzano-propiedades_glv
# 18946                                                                 https://www.properati.com.ar/1k0hf_venta_casa_villa-pueyrredon_suite_lavadero_parrilla_patio_quincho_terraza_toilette_vestidor_vista_otero-propiedades_f34
# 18948                                                                                                                      https://www.properati.com.ar/1k143_venta_departamento_villa-devoto_lavadero_sf-grupo-inmobiliario_ezs
# 18949                                                                                                              https://www.properati.com.ar/1k3zz_venta_departamento_villa-pueyrredon_balcon_luminoso_placard_re-max-avenida
# 18952                                                                              https://www.properati.com.ar/1k4jj_venta_casa_velez-sarsfield_balcon_suite_terraza_toilette_garage_aire-acondicionado_century-21-republicador
# 18953                                                                                   https://www.properati.com.ar/1k4n1_venta_ph_villa-pueyrredon_lavadero_patio_terraza_garage_apto-credito-hipotecario_roma-propiedades_hzx
# 18954                                                https://www.properati.com.ar/1k4pv_venta_ph_villa-pueyrredon_balcon_baulera_parrilla_luminoso_garage_aire-acondicionado_apto-credito-hipotecario_bienvende-amelia-claro_e77
# 18955                                                                                                                         https://www.properati.com.ar/1k4up_venta_departamento_villa-urquiza_riveros-negocios-inmobiliarios
# 18956                                                                                                                             https://www.properati.com.ar/1k4uq_venta_departamento_agronomia_riveros-negocios-inmobiliarios
# 18959                                              https://www.properati.com.ar/1k7w1_venta_ph_villa-pueyrredon_lavadero_parrilla_patio_quincho_terraza_luminoso_amoblado_impecable_placard_aire-acondicionado_re-max-premium-ii
# 18960                                                                                                                       https://www.properati.com.ar/1kb1t_venta_departamento_villa-pueyrredon_luminoso_placard_re-max-lagos
# 18961                                                                                                  https://www.properati.com.ar/1kelk_venta_casa_villa-pueyrredon_lavadero_parrilla_patio_terraza_garage_rcm-propiedades_c67
# 18962                                                                          https://www.properati.com.ar/1kem4_venta_ph_villa-pueyrredon_parrilla_patio_terraza_luminoso_placard_apto-credito-hipotecario_rcm-propiedades_c67
# 18963                                                                   https://www.properati.com.ar/1fakt_venta_departamento_villa-lugano_balcon_luminoso_garage_impecable_apto-credito-hipotecario_gabriel-torres-inmobiliaria
#
#                  barrio  comuna
# 2               PALERMO    14.0
# 5               PALERMO    14.0
# 6               PALERMO    14.0
# 8               PALERMO    14.0
# 9               PALERMO    14.0
# 11              PALERMO    14.0
# 12              PALERMO    14.0
# 13              PALERMO    14.0
# 14              PALERMO    14.0
# 15              PALERMO    14.0
# 18              PALERMO    14.0
# 20              PALERMO    14.0
# 21              PALERMO    14.0
# 22              PALERMO    14.0
# 24              PALERMO    14.0
# 25              PALERMO    14.0
# 29              PALERMO    14.0
# 31              PALERMO    14.0
# 35              PALERMO    14.0
# 37              PALERMO    14.0
# 38              PALERMO    14.0
# 39              PALERMO    14.0
# 40              PALERMO    14.0
# 42              PALERMO    14.0
# 43              PALERMO    14.0
# 44              PALERMO    14.0
# 52              PALERMO    14.0
# 53              PALERMO    14.0
# 55              PALERMO    14.0
# 56              PALERMO    14.0
# ...                 ...     ...
# 18924  VILLA PUEYRREDON    12.0
# 18925  VILLA PUEYRREDON    12.0
# 18926  VILLA PUEYRREDON    12.0
# 18927  VILLA PUEYRREDON    12.0
# 18928  VILLA PUEYRREDON    12.0
# 18929  VILLA PUEYRREDON    12.0
# 18931  VILLA PUEYRREDON    12.0
# 18932  VILLA PUEYRREDON    12.0
# 18933  VILLA PUEYRREDON    12.0
# 18934  VILLA PUEYRREDON    12.0
# 18935  VILLA PUEYRREDON    12.0
# 18936  VILLA PUEYRREDON    12.0
# 18939  VILLA PUEYRREDON    12.0
# 18941  VILLA PUEYRREDON    12.0
# 18942  VILLA PUEYRREDON    12.0
# 18943  VILLA PUEYRREDON    12.0
# 18944  VILLA PUEYRREDON    12.0
# 18946  VILLA PUEYRREDON    12.0
# 18948  VILLA PUEYRREDON    12.0
# 18949  VILLA PUEYRREDON    12.0
# 18952  VILLA PUEYRREDON    12.0
# 18953  VILLA PUEYRREDON    12.0
# 18954  VILLA PUEYRREDON    12.0
# 18955  VILLA PUEYRREDON    12.0
# 18956  VILLA PUEYRREDON    12.0
# 18959  VILLA PUEYRREDON    12.0
# 18960  VILLA PUEYRREDON    12.0
# 18961  VILLA PUEYRREDON    12.0
# 18962  VILLA PUEYRREDON    12.0
# 18963     VILLA SOLDATI     8.0
#
# [12833 rows x 17 columns]

# %% [markdown]
# A partir de quitar estos valores van a cambiar los estadísticos que calculamos.
#
# **12) Volvé a calcular** los mismos estadísticos (min, max, promedio, etc) para ver los cambios.
# ¿Por qué será que la **mediana** no cambia?

# %%
# Realizá los calculos en esta celda

min = df_filtered['price_usd_per_m2'].min()
max = df_filtered['price_usd_per_m2'].max()
mean = df_filtered['price_usd_per_m2'].mean()
median = df_filtered['price_usd_per_m2'].median()
std = df_filtered['price_usd_per_m2'].std()

print("Valor Minimo", min)
print("Valor Maximo", max)
print("Promedio", mean)
print("Mediana", median)
print("Desvio estandar", std)
# Out:
# Valor Minimo 1481.4814814814815
# Valor Maximo 4067.796610169493
# Promedio 2584.7275272312486
# Mediana 2545.436363636364
# Desvio estandar 615.3190268519706

# %% [markdown]
# Vamos a graficar ahora los barrios según el precio por metro cuadrado.

# %%
plt.xticks(rotation = 90)
barrios = df_filtered.groupby('barrio').mean().sort_values('price_usd_per_m2', ascending=False).index
sns.barplot(x="barrio", y="price_usd_per_m2", order=barrios, data=df_filtered);

# %% [markdown]
# #### Más caros

# %%
table = pd.pivot_table(df, values='price_usd_per_m2', index=['barrio'], aggfunc=np.mean)
mas_caros = table.sort_values('price_usd_per_m2', ascending=False).iloc[:5]
mas_caros
# Out:
#                price_usd_per_m2
# barrio
# PUERTO MADERO       6156.633183
# PALERMO             3632.057960
# RETIRO              3417.635657
# RECOLETA            3346.748987
# BELGRANO            3338.725206

# %% [markdown]
# #### Más baratos

# %%
table = pd.pivot_table(df, values='price_usd_per_m2', index=['barrio'], aggfunc=np.mean)
mas_baratos = table.sort_values('price_usd_per_m2', ascending=True).iloc[:5]
mas_baratos
# Out:
#                    price_usd_per_m2
# barrio
# VILLA SOLDATI            920.825753
# VILLA LUGANO            1179.846071
# VILLA RIACHUELO         1274.809950
# PARQUE AVELLANEDA       1386.260577
# NUEVA POMPEYA           1539.235869

# %% [markdown]
# ## Graficando propiedades de los barrios
#
# Ahora que ya sabemos cuales son los barrios más caros y cuales son los más baratos vamos a ver algunas comparaciones gráficas para entender mejor sus diferencias en diferentes atributos del dataset. Vamos a ver las distribuciones según:
# - Superficie total en m2
# - Cuartos totales
# - Precio en dolares por m2

# %%
barrios_caros = mas_caros.index 
barrios_baratos = mas_baratos.index

# %%
g = sns.distplot(df_filtered[df_filtered.barrio.isin(barrios_baratos)].surface_total_in_m2, label="Barrios baratos")
sns.distplot(df_filtered[df_filtered.barrio.isin(barrios_caros)].surface_total_in_m2, label="Barrios caros")
g.set_xlim(0, 400)
plt.legend()

# %%
g = sns.distplot(df_filtered[df_filtered.barrio.isin(barrios_baratos)].rooms.dropna(), label="Barrios baratos")
sns.distplot(df_filtered[df_filtered.barrio.isin(barrios_caros)].rooms.dropna(), label="Barrios caros")
g.set_xlim(0, 10)
plt.legend()

# %%
g = sns.distplot(df_filtered[df_filtered.barrio.isin(barrios_baratos)].price_usd_per_m2, label="Barrios baratos")
sns.distplot(df_filtered[df_filtered.barrio.isin(barrios_caros)].price_usd_per_m2, label="Barrios caros")
plt.legend()

# %% [markdown]
# ### Barrios que quieren ser otros

# %% [markdown]
# Basado en información de mercado, desde el portal Properati han señalado que las inmobiliarias suelen publicar las propiedades ubicadas en barrios que no necesariamente se corresponden con la ubicación geográfica real. Según mencionan en la nota ([blog)](http://blog.properati.com.ar/barrios-que-quieren-ser-otros/), esto corresponde a una lógica comercial en el corredor norte y a usos y costumbres en zona oeste.
#
# Analicemos qué sucede para nuestro dataset.

# %% [markdown]
# Dada la estructura del atributo `place_with_parent_names`, en primer lugar vamos a extraer el campo asociado al barrio publicado para poder comparar con el que surge de la cartografía oficial. Esto lo vamos a agregar en una nueva columna llamada `barrio_publicado`.
#
# De este modo, lo que vamos a analizar es como se relacionan las columnas `barrio` y `barrio publicado`. Si efectivamente hay barrios que quieren ser otros, esperaríamos ver propiedades ubicadas en geográficamente en un barrio distinto al que dice la publicación. Por ejemplo, si una propiedad está ubicada (dadas sus coordenadas) en Villa Crespo pero en la publicación dice Palermo, entonces decimos que hay indicios que Villa Crespo quiere ser Palermo.
#
# Viendo la estructura de este atributo, podemos notar que se compone por una sequencia de lugares separados por `|`. Por ejemplo, en `|Argentina|Capital Federal|Palermo|` vemos que primero está el país, luego la ciudad, luego el barrio y en algunos casos hay una jerarquía más, relacionado con zonas dentro del barrio (como Palermo Soho dentro de Palermo).
#
# De este modo, una estrategia posible para resolver esto es separar las jerarquías por `|` y extraer el elemento asociado al barrio. Por ejemplo, para `|Argentina|Capital Federal|Palermo|` queda `['', 'Argentina', 'Capital Federal', 'Palermo', '']`. Extrayendo el tercer elemento obtendremos el barrio independientemente de si hay lugares luego en la jerarquía. Aquellos que no tengan barrio no serán considerados puesto que estarían ubicados en Capital Federal y no sería informativo.
#
# Lo pasamos a mayúsculas y quitamos las tildes para poder comparar con el barrio oficial.

# %%
df_filtered['place_with_parent_names'].apply(lambda x: len(x.split("|"))).unique()
# Out:
# array([6, 5, 4])

# %% [markdown]
# Como algunos tienen 4 elementos, debemos quitarlos.

# %%
split_place_filter = df_filtered['place_with_parent_names'].apply(lambda x: len(x.split("|"))!=4)
df_filtered = df_filtered.loc[split_place_filter]

# %%
df_filtered['barrio_publicado'] = df_filtered['place_with_parent_names'].apply( lambda x: x.split("|")[3].upper())
df_filtered['barrio_publicado'] = df_filtered['barrio_publicado'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
# Out:
# /home/willy.aguirre/anaconda2/envs/acamica/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/willy.aguirre/anaconda2/envs/acamica/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Comparemos entonces el barrio publicado con el real. Nos vamos a quedar con aquellas propiedades donde nos coincidan para luego hacer el conteo por barrio.

# %%
barrios_match = (df_filtered['barrio_publicado'] != df_filtered['barrio'])
df_filtered_barrio_not_match = df_filtered.loc[barrios_match]

# %% [markdown]
# Con una tabla de doble entrada podemos identificar para cada barrio cuál es al que más quiere parecerse.

# %%
table = pd.crosstab(df_filtered_barrio_not_match.barrio, df_filtered_barrio_not_match.barrio_publicado)
table.idxmax(axis=1)
# Out:
# barrio
# AGRONOMIA                VILLA PUEYRREDON
# ALMAGRO                           PALERMO
# BALVANERA                            ONCE
# BARRACAS                        SAN TELMO
# BELGRANO                            NUNEZ
# BOCA                             BARRACAS
# BOEDO                    PARQUE PATRICIOS
# CABALLITO               PARQUE CENTENARIO
# CHACARITA                      COLEGIALES
# COGHLAN                          BELGRANO
# COLEGIALES                       BELGRANO
# CONSTITUCION                    SAN TELMO
# FLORES                          CABALLITO
# FLORESTA                           FLORES
# LINIERS                        VILLA LURO
# MATADEROS                         LINIERS
# MONSERRAT                       SAN TELMO
# MONTE CASTRO                 VILLA DEVOTO
# NUEVA POMPEYA            PARQUE PATRICIOS
# NUEZ                                NUNEZ
# PALERMO                          BELGRANO
# PARQUE AVELLANEDA                FLORESTA
# PARQUE CHACABUCO                CABALLITO
# PARQUE CHAS                 VILLA URQUIZA
# PARQUE PATRICIOS            SAN CRISTOBAL
# PATERNAL                     VILLA CRESPO
# RECOLETA                     BARRIO NORTE
# RETIRO                           RECOLETA
# SAAVEDRA                            NUNEZ
# SAN CRISTOBAL                       BOEDO
# SAN NICOLAS          CENTRO / MICROCENTRO
# SAN TELMO                   SAN CRISTOBAL
# VELEZ SARSFIELD                  FLORESTA
# VILLA CRESPO                      PALERMO
# VILLA DEL PARQUE             VILLA DEVOTO
# VILLA DEVOTO             VILLA PUEYRREDON
# VILLA GRAL. MITRE     VILLA GENERAL MITRE
# VILLA LURO                      VERSALLES
# VILLA ORTUZAR               VILLA URQUIZA
# VILLA PUEYRREDON            VILLA URQUIZA
# VILLA REAL                      VERSALLES
# VILLA RIACHUELO              VILLA LUGANO
# VILLA SANTA RITA         VILLA DEL PARQUE
# VILLA SOLDATI                VILLA LUGANO
# VILLA URQUIZA                    BELGRANO
# dtype: object

# %% [markdown]
# Podemos ver entonces que los barrios tienden a querer parecerse a barrios con precio con metro cuadrado más caro. Por ejemplo Villa Crespo con Palermo, Constitución con San Telmo y Villa Urquiza con Belgrano.
#
# Por otro lado, vemos también que los barrios suelen querer parecerse a sus barrios vecinos.
